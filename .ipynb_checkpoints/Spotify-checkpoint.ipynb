# %%
import sklearn as sk
import sklearn.tree as tree
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import make_scorer
import pickle
import matplotlib.pyplot as plt

# %%
pip install lazypredict

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('data.csv')
df
# Out:
#       Index                   Title                    Artist  \
# 0         1                 Sunrise               Norah Jones
# 1         2             Black Night               Deep Purple
# 2         3          Clint Eastwood                  Gorillaz
# 3         4           The Pretender              Foo Fighters
# 4         5  Waitin' On A Sunny Day         Bruce Springsteen
# ...     ...                     ...                       ...
# 1944   1990        Heartbreak Hotel             Elvis Presley
# 1945   1991               Hound Dog             Elvis Presley
# 1946   1992         Johnny B. Goode               Chuck Berry
# 1947   1993               Take Five  The Dave Brubeck Quartet
# 1948   1994          Blueberry Hill               Fats Domino
#
#                 Top Genre  Year  Beats Per Minute (BPM)  Energy  Danceability  \
# 0         adult standards  2004                     157      30            53
# 1              album rock  2000                     135      79            50
# 2     alternative hip hop  2001                     168      69            66
# 3       alternative metal  2007                     173      96            43
# 4            classic rock  2002                     106      82            58
# ...                   ...   ...                     ...     ...           ...
# 1944      adult standards  1958                      94      21            70
# 1945      adult standards  1958                     175      76            36
# 1946           blues rock  1959                     168      80            53
# 1947                bebop  1959                     174      26            45
# 1948      adult standards  1959                     133      50            49
#
#       Loudness (dB)  Liveness  Valence  Length (Duration)  Acousticness  \
# 0               -14        11       68                201            94
# 1               -11        17       81                207            17
# 2                -9         7       52                341             2
# 3                -4         3       37                269             0
# 4                -5        10       87                256             1
# ...             ...       ...      ...                ...           ...
# 1944            -12        11       72                128            84
# 1945             -8        76       95                136            73
# 1946             -9        31       97                162            74
# 1947            -13         7       60                324            54
# 1948            -10        16       83                148            74
#
#       Speechiness  Popularity
# 0               3          71
# 1               7          39
# 2              17          69
# 3               4          76
# 4               3          59
# ...           ...         ...
# 1944            7          63
# 1945            6          69
# 1946            7          74
# 1947            4          65
# 1948            3          56
#
# [1949 rows x 15 columns]

# %%
df.drop(columns = ['Index', 'Title', 'Artist', 'Year'], inplace = True)

# %%
attributes = df.columns[1:]
for attribute in attributes:
    temp = df[attribute]
    for instance in range(len(temp)):
        if(type(temp[instance]) == str):
            df[attribute][instance] = float(temp[instance].replace(',',''))

# %%
genre = (df["Top Genre"].str.strip()).str.lower()

# %%
def genre_splitter(genre):
    result = genre.copy()
    result = result.str.split(" ",1)
    for i in range(len(result)):
        if (len(result[i]) > 1):
            result[i] = [result[i][1]]
    return result.str.join('')

# %%
genre_m1 = genre.copy()
while(max((genre_m1.str.split(" ", 1)).str.len()) > 1):
    genre_m1 = genre_splitter(genre_m1)
# Out:
# /tmp/ipykernel_1344/405489067.py:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   while(max((genre_m1.str.split(" ", 1)).str.len()) > 1):
# /tmp/ipykernel_1344/2429127237.py:3: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   result = result.str.split(" ",1)

# %%
len(genre_m1.unique())
# Out:
# 66

# %%
df.isnull().any()
# Out:
# Top Genre                 False
# Beats Per Minute (BPM)    False
# Energy                    False
# Danceability              False
# Loudness (dB)             False
# Liveness                  False
# Valence                   False
# Length (Duration)         False
# Acousticness              False
# Speechiness               False
# Popularity                False
# dtype: bool

# %%
len(df["Top Genre"].unique())
# Out:
# 147

# %%
df.dtypes
# Out:
# Top Genre                 object
# Beats Per Minute (BPM)     int64
# Energy                     int64
# Danceability               int64
# Loudness (dB)              int64
# Liveness                   int64
# Valence                    int64
# Length (Duration)          int64
# Acousticness               int64
# Speechiness                int64
# Popularity                 int64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df.corr(),annot=False)
# Out:
# /tmp/ipykernel_1344/2755843488.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=False)
# <AxesSubplot: >

# %%
rs = np.random.RandomState(0)
df2 = pd.DataFrame(rs.rand(15,15))
corr = df2.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_358e0_row0_col0, #T_358e0_row1_col1, #T_358e0_row2_col2, #T_358e0_row3_col3, #T_358e0_row4_col4, #T_358e0_row5_col5, #T_358e0_row6_col6, #T_358e0_row7_col7, #T_358e0_row8_col8, #T_358e0_row9_col9, #T_358e0_row10_col10, #T_358e0_row11_col11, #T_358e0_row12_col12, #T_358e0_row13_col13, #T_358e0_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_358e0_row0_col1, #T_358e0_row0_col6, #T_358e0_row0_col14, #T_358e0_row2_col13, #T_358e0_row3_col11, #T_358e0_row6_col0, #T_358e0_row6_col2, #T_358e0_row6_col9, #T_358e0_row10_col7, #T_358e0_row11_col2, #T_358e0_row11_col3, #T_358e0_row11_col4, #T_358e0_row11_col5, #T_358e0_row11_col8, #T_358e0_row11_col10, #T_358e0_row11_col12, #T_358e0_row12_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_358e0_row0_col2, #T_358e0_row3_col9, #T_358e0_row14_col11 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_358e0_row0_col3, #T_358e0_row3_col0, #T_358e0_row6_col4, #T_358e0_row14_col8 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_358e0_row0_col4, #T_358e0_row0_col8 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_358e0_row0_col5, #T_358e0_row4_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_358e0_row0_col7, #T_358e0_row2_col14, #T_358e0_row12_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_358e0_row0_col9 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_358e0_row0_col10, #T_358e0_row7_col10 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_358e0_row0_col11 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_358e0_row0_col12 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_358e0_row0_col13 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_358e0_row1_col0, #T_358e0_row6_col13, #T_358e0_row13_col9 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_358e0_row1_col2, #T_358e0_row9_col4 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_358e0_row1_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_358e0_row1_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_358e0_row1_col5, #T_358e0_row1_col9, #T_358e0_row2_col6, #T_358e0_row4_col8, #T_358e0_row10_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_358e0_row1_col6, #T_358e0_row8_col1 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_358e0_row1_col7 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_358e0_row1_col8 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_358e0_row1_col10, #T_358e0_row8_col12, #T_358e0_row13_col11, #T_358e0_row14_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_358e0_row1_col11, #T_358e0_row4_col3, #T_358e0_row7_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_358e0_row1_col12 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_358e0_row1_col13 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_358e0_row1_col14 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_358e0_row2_col0, #T_358e0_row5_col7 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_358e0_row2_col1, #T_358e0_row3_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_358e0_row2_col3, #T_358e0_row7_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_358e0_row2_col4, #T_358e0_row4_col2 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_358e0_row2_col5, #T_358e0_row3_col12, #T_358e0_row12_col6 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_358e0_row2_col7, #T_358e0_row7_col2, #T_358e0_row7_col12 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_358e0_row2_col8, #T_358e0_row10_col12 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_358e0_row2_col9, #T_358e0_row3_col10 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_358e0_row2_col10 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_358e0_row2_col11 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_358e0_row2_col12 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_358e0_row3_col1, #T_358e0_row10_col14 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_358e0_row3_col2, #T_358e0_row6_col7, #T_358e0_row11_col14, #T_358e0_row12_col9, #T_358e0_row14_col12 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_358e0_row3_col4, #T_358e0_row14_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_358e0_row3_col5 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_358e0_row3_col6, #T_358e0_row12_col13 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_358e0_row3_col8 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_358e0_row3_col13 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_358e0_row3_col14, #T_358e0_row9_col6 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_358e0_row4_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_358e0_row4_col5, #T_358e0_row7_col9, #T_358e0_row13_col3 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_358e0_row4_col6 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_358e0_row4_col7 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_358e0_row4_col9, #T_358e0_row7_col8 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_358e0_row4_col10, #T_358e0_row10_col9 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_358e0_row4_col11, #T_358e0_row9_col8, #T_358e0_row9_col14, #T_358e0_row13_col8 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_358e0_row4_col12, #T_358e0_row5_col4, #T_358e0_row9_col12 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_358e0_row4_col13 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_358e0_row4_col14, #T_358e0_row12_col8 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_358e0_row5_col0, #T_358e0_row13_col10 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_358e0_row5_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_358e0_row5_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_358e0_row5_col3, #T_358e0_row12_col3 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_358e0_row5_col6, #T_358e0_row8_col5, #T_358e0_row11_col7 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_358e0_row5_col8, #T_358e0_row7_col1 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_358e0_row5_col9, #T_358e0_row8_col14 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_358e0_row5_col10 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_358e0_row5_col11 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_358e0_row5_col12, #T_358e0_row6_col11, #T_358e0_row11_col6, #T_358e0_row11_col9 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_358e0_row5_col13, #T_358e0_row9_col10 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_358e0_row5_col14, #T_358e0_row10_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_358e0_row6_col1 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_358e0_row6_col3, #T_358e0_row6_col5, #T_358e0_row14_col3 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_358e0_row6_col8, #T_358e0_row12_col5 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_358e0_row6_col10, #T_358e0_row13_col12 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_358e0_row6_col12, #T_358e0_row7_col11 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_358e0_row6_col14 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_358e0_row7_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_358e0_row7_col4 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_358e0_row7_col5, #T_358e0_row10_col2, #T_358e0_row10_col3 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_358e0_row7_col13, #T_358e0_row8_col0, #T_358e0_row12_col11 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_358e0_row7_col14 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_358e0_row8_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_358e0_row8_col3 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_358e0_row8_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_358e0_row8_col6 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_358e0_row8_col7 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_358e0_row8_col9 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_358e0_row8_col10 {
#   background-colo

# %%
genre_m1.value_counts()
# Out:
# rock           836
# pop            331
# standards      115
# metal           92
# indie           77
#               ...
# holler           1
# electronica      1
# hardcore         1
# trance           1
# bebop            1
# Name: Top Genre, Length: 66, dtype: int64

# %%
df.rename(columns = {'Top Genre':'Genre'}, inplace = True)

# %%
df['Genre'] = genre_m1
df
# Out:
#           Genre  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# 0     standards                     157      30            53            -14
# 1          rock                     135      79            50            -11
# 2           hop                     168      69            66             -9
# 3         metal                     173      96            43             -4
# 4          rock                     106      82            58             -5
# ...         ...                     ...     ...           ...            ...
# 1944  standards                      94      21            70            -12
# 1945  standards                     175      76            36             -8
# 1946       rock                     168      80            53             -9
# 1947      bebop                     174      26            45            -13
# 1948  standards                     133      50            49            -10
#
#       Liveness  Valence  Length (Duration)  Acousticness  Speechiness  \
# 0           11       68                201            94            3
# 1           17       81                207            17            7
# 2            7       52                341             2           17
# 3            3       37                269             0            4
# 4           10       87                256             1            3
# ...        ...      ...                ...           ...          ...
# 1944        11       72                128            84            7
# 1945        76       95                136            73            6
# 1946        31       97                162            74            7
# 1947         7       60                324            54            4
# 1948        16       83                148            74            3
#
#       Popularity
# 0             71
# 1             39
# 2             69
# 3             76
# 4             59
# ...          ...
# 1944          63
# 1945          69
# 1946          74
# 1947          65
# 1948          56
#
# [1949 rows x 11 columns]

# %%
unique = genre_m1.unique()
to_remove = [] 

# genres that have a single instance only will be placed within the to_remove array
for genre in unique:
    if genre_m1.value_counts()[genre] < 20: # 10 was arbitrarily chosen
        to_remove += [genre]
len(to_remove)
# Out:
# 55

# %%
df.set_index(["Genre"],drop = False, inplace = True)
for name in to_remove:
    type(name)
    df.drop(index = str(name), inplace = True)

# %%
sns.catplot(data=df,x = 'Acousticness', y='Popularity', kind="bar")

# %%
sns.catplot(data=df,x = 'Beats Per Minute (BPM)', y='Energy', kind="bar")

# %%
sns.catplot(data=df,x = 'Genre', y='Popularity', kind="bar")

# %%
sns.catplot(data=df,x = 'Genre', y='Speechiness', kind="bar")

# %%
sns.catplot(data=df,x = 'Genre', y='Acousticness', kind="bar")

# %%
sns.catplot(data=df,x = 'Genre', y='Length (Duration)', kind="bar")

# %%
sns.catplot(data=df,x = 'Danceability', y='Popularity', kind="bar")

# %%
sns.catplot(data=df,x = 'Danceability', y='Energy', kind="bar")

# %%
sns.catplot(data=df,x = 'Genre', y='Danceability', kind="bar")

# %%
sns.catplot(data=df,x = 'Genre', y='Energy', kind="bar")

# %%
sns.pairplot(df[['Danceability' ,'Loudness (dB)', 'Liveness']])

# %%
sns.pairplot(df[['Length (Duration)' ,'Speechiness', 'Energy']])

# %%
sns.pairplot(df[['Speechiness' ,'Popularity', 'Energy']])

# %%
def transform(feature):
    le=LabelEncoder()
    df[feature]=le.fit_transform(df[feature])

# %%
cat_df=df.select_dtypes(include='object')
cat_df.columns
# Out:
# Index(['Genre'], dtype='object')

# %%
for col in cat_df.columns:
    transform(col)

df
# Out:
#            Genre  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# Genre
# standards      9                     157      30            53            -14
# rock           7                     135      79            50            -11
# hop            2                     168      69            66             -9
# metal          5                     173      96            43             -4
# rock           7                     106      82            58             -5
# ...          ...                     ...     ...           ...            ...
# standards      9                     168       7            17            -21
# standards      9                      94      21            70            -12
# standards      9                     175      76            36             -8
# rock           7                     168      80            53             -9
# standards      9                     133      50            49            -10
#
#            Liveness  Valence  Length (Duration)  Acousticness  Speechiness  \
# Genre
# standards        11       68                201            94            3
# rock             17       81                207            17            7
# hop               7       52                341             2           17
# metal             3       37                269             0            4
# rock             10       87                256             1            3
# ...             ...      ...                ...           ...          ...
# standards        14       10                298            92            3
# standards        11       72                128            84            7
# standards        76       95                136            73            6
# rock             31       97                162            74            7
# standards        16       83                148            74            3
#
#            Popularity
# Genre
# standards          71
# rock               39
# hop                69
# metal              76
# rock               59
# ...               ...
# standards          66
# standards          63
# standards          69
# rock               74
# standards          56
#
# [1674 rows x 11 columns]

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [37], line 1
# ----> 1 from bokeh.plotting import figure, show
#       2 from bokeh.io import output_notebook
#
# ModuleNotFoundError: No module named 'bokeh'

# %%
X = df.drop('Genre',axis=1)
Y = df.Genre

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.15)
X_train,X_val,y_train,y_val=train_test_split(X_train,y_train,test_size=0.15)

# %%
from sklearn.preprocessing import StandardScaler

standard_scaler = StandardScaler().fit(X_train)

# Standard Scaler
X_train_ST = standard_scaler.transform(X_train)
X_test_ST = standard_scaler.transform(X_test)

# %%
unique = np.unique(y_train)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

rand_forest = RandomForestClassifier(random_state = 42, min_samples_split = 5)
clf = LogisticRegression(multi_class = 'ovr')

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
result_ST =[]
kfold = StratifiedKFold(n_splits = 5, random_state = 1, shuffle = True)
RF_cross_val_score = cross_val_score(rand_forest, X_train_ST, y_train, cv = kfold, scoring = 'accuracy')
print('%s: %f (%f)' % ('Random Forest', RF_cross_val_score.mean(), RF_cross_val_score.std()))

# %%
kfold = StratifiedKFold(n_splits = 5, random_state = 1, shuffle = True)
RF_cross_val_score = cross_val_score(clf, X_train_ST, y_train, cv = kfold, scoring = 'accuracy')
print('%s: %f (%f)' % ('Random Forest', RF_cross_val_score.mean(), RF_cross_val_score.std()))

# %%
kfold = StratifiedKFold(n_splits = 5, random_state = 1, shuffle = True)
