# %%
import sklearn as sk
import sklearn.tree as tree
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import make_scorer
import pickle
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('data2.csv')
df
# Out:
#              artist_name                      id  \
# 0          Missy Elliott  0UaMYEvWZi0ZqiDOoHU3YI
# 1         Britney Spears  6I9VzXrHxO9rA9A5euc8Ak
# 2                Beyoncé  0WqIKmW4BTrj3eJFmnCKMv
# 3      Justin Timberlake  1AWQoqb9bSvzTjaLralEkT
# 4                 Shaggy  1lzr43nnXAijIGYnCT8M8H
# ...                  ...                     ...
# 34242              Jon D  3uCHI1gfOUL5j5swEh0TcH
# 34243          Big Words  0P1oO2gREMYUCoOkzYAyFu
# 34244       Allan Rayman  2oM4BuruDnEvk59IvIXCwn
# 34245          Jon Jason  4Ri5TTUgjM96tbQZd5Ua7V
# 34246           Grizfolk  5RVuBrXVLptAEbGJdSDzL5
#
#                                          track_name  danceability  energy  \
# 0        Lose Control (feat. Ciara & Fat Man Scoop)         0.904   0.813
# 1                                             Toxic         0.774   0.838
# 2                                     Crazy In Love         0.664   0.758
# 3                                    Rock Your Body         0.892   0.714
# 4                                      It Wasn't Me         0.853   0.606
# ...                                             ...           ...     ...
# 34242                                  I Don't Know         0.669   0.228
# 34243                                    The Answer         0.493   0.727
# 34244                                         25.22         0.702   0.524
# 34245                                  Good Feeling         0.509   0.286
# 34246  Cosmic Angel - Acoustic From Capitol Studios         0.639   0.461
#
#        key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0        4    -7.105     0       0.1210       0.03110          0.006970
# 1        5    -3.914     0       0.1140       0.02490          0.025000
# 2        2    -6.583     0       0.2100       0.00238          0.000000
# 3        4    -6.055     0       0.1410       0.20100          0.000234
# 4        0    -4.596     1       0.0713       0.05610          0.000000
# ...    ...       ...   ...          ...           ...               ...
# 34242    2   -12.119     1       0.0690       0.79200          0.065000
# 34243    1    -5.031     1       0.2170       0.08730          0.000000
# 34244    7   -10.710     1       0.0793       0.33200          0.055300
# 34245    8   -14.722     1       0.1230       0.40200          0.000012
# 34246    6    -8.260     0       0.0493       0.35700          0.000057
#
#        liveness  valence    tempo  artist_pop  \
# 0        0.0471    0.810  125.461          74
# 1        0.2420    0.924  143.040          84
# 2        0.0598    0.701   99.259          86
# 3        0.0521    0.817  100.972          82
# 4        0.3130    0.654   94.759          75
# ...         ...      ...      ...         ...
# 34242    0.0944    0.402   83.024          47
# 34243    0.1290    0.289   73.259          39
# 34244    0.2980    0.265  140.089          55
# 34245    0.1310    0.259  121.633           4
# 34246    0.1120    0.264  117.583          53
#
#                                                   genres  track_pop  \
# 0      dance_pop hip_hop hip_pop pop pop_rap r&b rap ...         69
# 1                            dance_pop pop post-teen_pop         83
# 2                                      dance_pop pop r&b         25
# 3                                          dance_pop pop         79
# 4                                  pop_rap reggae_fusion          2
# ...                                                  ...        ...
# 34242                                            unknown         27
# 34243                                     australian_r&b         37
# 34244  canadian_contemporary_r&b modern_alternative_rock         49
# 34245                                            unknown         16
# 34246  indie_poptimism indiecoustica modern_alternati...         40
#
#                                              genres_list subjectivity  \
# 0      ['dance_pop', 'hip_hop', 'hip_pop', 'pop', 'po...          low
# 1                  ['dance_pop', 'pop', 'post-teen_pop']          low
# 2                            ['dance_pop', 'pop', 'r&b']         high
# 3                                   ['dance_pop', 'pop']          low
# 4                           ['pop_rap', 'reggae_fusion']          low
# ...                                                  ...          ...
# 34242                                        ['unknown']          low
# 34243                                 ['australian_r&b']          low
# 34244  ['canadian_contemporary_r&b', 'modern_alternat...          low
# 34245                                        ['unknown']         high
# 34246  ['indie_poptimism', 'indiecoustica', 'modern_a...          low
#
#        polarity
# 0       Neutral
# 1       Neutral
# 2      Negative
# 3       Neutral
# 4       Neutral
# ...         ...
# 34242   Neutral
# 34243   Neutral
# 34244   Neutral
# 34245  Positive
# 34246   Neutral
#
# [34247 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34247 entries, 0 to 34246
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist_name       34247 non-null  object
#  1   id                34247 non-null  object
#  2   track_name        34247 non-null  object
#  3   danceability      34247 non-null  float64
#  4   energy            34247 non-null  float64
#  5   key               34247 non-null  int64
#  6   loudness          34247 non-null  float64
#  7   mode              34247 non-null  int64
#  8   speechiness       34247 non-null  float64
#  9   acousticness      34247 non-null  float64
#  10  instrumentalness  34247 non-null  float64
#  11  liveness          34247 non-null  float64
#  12  valence           34247 non-null  float64
#  13  tempo             34247 non-null  float64
#  14  artist_pop        34247 non-null  int64
#  15  genres            34247 non-null  object
#  16  track_pop         34247 non-null  int64
#  17  genres_list       34247 non-null  object
#  18  subjectivity      34247 non-null  object
#  19  polarity          34247 non-null  object
# dtypes: float64(9), int64(4), object(7)
# memory usage: 5.2+ MB

# %%
df.shape
# Out:
# (34247, 20)

# %%
df.describe()
# Out:
#        danceability        energy           key      loudness          mode  \
# count  34247.000000  34247.000000  34247.000000  34247.000000  34247.000000
# mean       0.584693      0.636613      5.214209     -7.606617      0.665080
# std        0.164307      0.225477      3.583579      3.967167      0.471969
# min        0.000000      0.000000      0.000000    -60.000000      0.000000
# 25%        0.476000      0.490000      2.000000     -9.165500      0.000000
# 50%        0.592000      0.669000      5.000000     -6.695000      1.000000
# 75%        0.705000      0.818000      8.000000     -5.002000      1.000000
# max        0.988000      1.000000     11.000000      2.766000      1.000000
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  34247.000000  34247.000000      34247.000000  34247.000000
# mean       0.091165      0.263740          0.077185      0.197244
# std        0.101096      0.300548          0.218725      0.166794
# min        0.000000      0.000000          0.000000      0.000000
# 25%        0.035100      0.020100          0.000000      0.095800
# 50%        0.048900      0.126000          0.000008      0.128000
# 75%        0.095800      0.445000          0.002700      0.252000
# max        0.962000      0.996000          0.995000      1.000000
#
#             valence         tempo    artist_pop     track_pop
# count  34247.000000  34247.000000  34247.000000  34247.000000
# mean       0.486016    121.703229     61.916606     31.114959
# std        0.243630     29.296913     19.120147     25.468451
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.292000     98.623000     51.000000      0.000000
# 50%        0.477000    120.930000     65.000000     34.000000
# 75%        0.677000    140.032000     76.000000     53.000000
# max        0.998000    219.297000    100.000000     97.000000

# %%
count = df.nunique()
count = count.sort_values()
count
# Out:
# mode                    2
# polarity                3
# subjectivity            3
# key                    12
# track_pop              95
# artist_pop             99
# danceability          924
# speechiness          1346
# energy               1357
# valence              1487
# liveness             1643
# acousticness         3933
# instrumentalness     4881
# genres               5991
# genres_list          5991
# artist_name          9722
# loudness            12156
# tempo               24362
# track_name          30046
# id                  34247
# dtype: int64

# %%
df.drop(['id', 'artist_name','track_name','artist_pop','genres_list'],axis=1,inplace=True)

# %%
count = df.nunique()
count = count.sort_values()
count
# Out:
# mode                    2
# subjectivity            3
# polarity                3
# key                    12
# track_pop              95
# danceability          924
# speechiness          1346
# energy               1357
# valence              1487
# liveness             1643
# acousticness         3933
# instrumentalness     4881
# genres               5991
# loudness            12156
# tempo               24362
# dtype: int64

# %%
df.skew()
# Out:
# danceability       -0.283729
# energy             -0.584381
# key                 0.021665
# loudness           -1.956228
# mode               -0.699578
# speechiness         2.881593
# acousticness        1.045306
# instrumentalness    2.981368
# liveness            2.201000
# valence             0.126693
# tempo               0.311184
# track_pop           0.062450
# dtype: float64

# %%
columns = ['speechiness', 'acousticness', 'instrumentalness', 'liveness']
for col in columns:
    df[col] = np.sqrt(df[col])

# %%
df.skew()
# Out:
# danceability       -0.283729
# energy             -0.584381
# key                 0.021665
# loudness           -1.956228
# mode               -0.699578
# speechiness         1.750408
# acousticness        0.412073
# instrumentalness    2.409801
# liveness            1.327290
# valence             0.126693
# tempo               0.311184
# track_pop           0.062450
# dtype: float64

# %%
columns = ['speechiness', 'instrumentalness', 'liveness']
for col in columns:
    df[col] = np.sqrt(df[col])

# %%
df.skew()
# Out:
# danceability       -0.283729
# energy             -0.584381
# key                 0.021665
# loudness           -1.956228
# mode               -0.699578
# speechiness         1.290984
# acousticness        0.412073
# instrumentalness    1.716450
# liveness            0.880255
# valence             0.126693
# tempo               0.311184
# track_pop           0.062450
# dtype: float64

# %%
columns = ['speechiness', 'instrumentalness']
for col in columns:
    df[col] = np.sqrt(df[col])

# %%
df.skew()
# Out:
# danceability       -0.283729
# energy             -0.584381
# key                 0.021665
# loudness           -1.956228
# mode               -0.699578
# speechiness         0.594164
# acousticness        0.412073
# instrumentalness    0.836126
# liveness            0.880255
# valence             0.126693
# tempo               0.311184
# track_pop           0.062450
# dtype: float64

# %%
genre = (df["genres"].str.strip()).str.lower()

# %%
def genre_splitter(genre):
    result = genre.copy()
    result = result.str.split(" ",1)
    for i in range(len(result)):
        if (len(result[i]) > 1):
            result[i] = [result[i][1]]
    return result.str.join('')

# %%
genre_m1 = genre.copy()
while(max((genre_m1.str.split(" ", 1)).str.len()) > 1):
    genre_m1 = genre_splitter(genre_m1)

# %%
len(genre_m1.unique())
# Out:
# 1329

# %%
genre_m1.value_counts()
# Out:
# unknown                       2047
# rock                          2015
# trap                          1515
# urban_contemporary            1491
# stomp_and_holler               961
#                               ...
# vintage_french_psychedelic       1
# indie_shoegaze                   1
# sitar                            1
# traditional_soul                 1
# musica_potosina                  1
# Name: genres, Length: 1329, dtype: int64

# %%
df['genres'] = genre_m1

# %%
df.set_index(["genres"],drop = False, inplace = True)
df.drop(index = "unknown", inplace = True)

# %%
main_genres = ['rock','pop','blues','hip_hop','jazz','reggae','techno','trap','regga','rap','r&b','country','soul','house','contemporary','folk','blues','indie','electronic','music','gothic','punk']
def check_genre(sir):
    for word in main_genres:
        if sir.find(word) != -1:
            if word == 'rap':
                return 'hip_hop'
            else:
                return word
    return sir

df['genres'] = df['genres'].apply(check_genre)
genre = (df["genres"].str.strip()).str.lower()

# %%
genre_m1 = genre.copy()
genre_m1
genre_m1.value_counts()
# Out:
# pop                    5965
# rock                   5574
# hip_hop                2686
# trap                   2334
# contemporary           1502
#                        ...
# gothic                    1
# zouk                      1
# chinese_traditional       1
# canadian_latin            1
# steel_guitar              1
# Name: genres, Length: 565, dtype: int64

# %%
unique = genre_m1.unique()

# %%
unique = genre_m1.unique()
to_remove = [] 

# genres that have a single instance only will be placed within the to_remove array
for genre in unique:
    if genre_m1.value_counts()[genre] < 170: # 10 was arbitrarily chosen
        to_remove += [genre]
len(to_remove)
# Out:
# 544

# %%
df.set_index(["genres"],drop = False, inplace = True)
for name in to_remove:
    type(name)
    df.drop(index = str(name), inplace = True)

# %%
genre = (df["genres"].str.strip()).str.lower()

# %%
genre_m1 = genre.copy()
genre_m1
genre_m1.value_counts()
# Out:
# pop                  5965
# rock                 5574
# hip_hop              2686
# trap                 2334
# contemporary         1502
# country              1008
# house                1007
# stomp_and_holler      961
# soul                  786
# indie                 780
# worship               614
# reggae                398
# jazz                  380
# r&b                   343
# punk                  340
# singer-songwriter     301
# show_tunes            290
# screamo               254
# post-grunge           195
# regional_mexican      185
# tropical              174
# Name: genres, dtype: int64

# %%
main_genres = ['rock','pop','blues','hip_hop','jazz','reggae','techno','trap','regga','rap','r&b','country','soul','house','contemporary','folk','blues','indie','electronic','music','gothic','punk']
def check_genre(sir):
    for word in main_genres:
        if sir.find(word) != -1:
            if word == 'rap':
                return 'hip_hop'
            else:
                return word
    return sir

df['genres'] = df['genres'].apply(check_genre)
genre = (df["genres"].str.strip()).str.lower()

# %%
genre_m1 = genre.copy()
genre_m1
genre_m1.value_counts()
# Out:
# pop                  5965
# rock                 5574
# hip_hop              2686
# trap                 2334
# contemporary         1502
# country              1008
# house                1007
# stomp_and_holler      961
# soul                  786
# indie                 780
# worship               614
# reggae                398
# jazz                  380
# r&b                   343
# punk                  340
# singer-songwriter     301
# show_tunes            290
# screamo               254
# post-grunge           195
# regional_mexican      185
# tropical              174
# Name: genres, dtype: int64

# %%
len(genre_m1.unique())
# Out:
# 21

# %%
df
# Out:
#          danceability  energy  key  loudness  mode  speechiness  acousticness  \
# genres
# hip_hop         0.904   0.813    4    -7.105     0     0.767977      0.176352
# pop             0.774   0.838    5    -3.914     0     0.762278      0.157797
# r&b             0.664   0.758    2    -6.583     0     0.822768      0.048785
# pop             0.892   0.714    4    -6.055     0     0.782803      0.448330
# reggae          0.853   0.606    0    -4.596     1     0.718847      0.236854
# ...               ...     ...  ...       ...   ...          ...           ...
# pop             0.458   0.650    5    -6.581     1     0.653590      0.417133
# soul            0.416   0.394   11    -9.269     1     0.709345      0.716240
# r&b             0.493   0.727    1    -5.031     1     0.826147      0.295466
# rock            0.702   0.524    7   -10.710     1     0.728466      0.576194
# rock            0.639   0.461    6    -8.260     0     0.686445      0.597495
#
#          instrumentalness  liveness  valence    tempo   genres  track_pop  \
# genres
# hip_hop          0.537532  0.465860    0.810  125.461  hip_hop         69
# pop              0.630583  0.701381    0.924  143.040      pop         83
# r&b              0.000000  0.494510    0.701   99.259      r&b         25
# pop              0.351683  0.477760    0.817  100.972      pop         79
# reggae           0.000000  0.747973    0.654   94.759   reggae          2
# ...                   ...       ...      ...      ...      ...        ...
# pop              0.000000  0.542318    0.341   77.953      pop         20
# soul             0.445442  0.560647    0.131   81.988     soul          0
# r&b              0.000000  0.599304    0.289   73.259      r&b         37
# rock             0.696371  0.738846    0.265  140.089     rock         49
# rock             0.294511  0.578502    0.264  117.583     rock         40
#
#         subjectivity  polarity
# genres
# hip_hop          low   Neutral
# pop              low   Neutral
# r&b             high  Negative
# pop              low   Neutral
# reggae           low   Neutral
# ...              ...       ...
# pop             high   Neutral
# soul             low   Neutral
# r&b              low   Neutral
# rock             low   Neutral
# rock             low   Neutral
#
# [26077 rows x 15 columns]

# %%
print(sns)
# Out:
# <module 'seaborn' from 'C:\\Users\\hemre\\python\\odev\\env\\lib\\site-packages\\seaborn\\__init__.py'>

# %%
sns.catplot(data=df,x = 'genre', y='tempo', kind="bar")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 sns.catplot(data=df,x = 'genre', y='tempo', kind="bar")
#
# File ~\python\odev\env\lib\site-packages\seaborn\categorical.py:3183, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3181 p = _CategoricalPlotter()
#    3182 p.require_numeric = plotter_class.require_numeric
# -> 3183 p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3184 if (
#    3185     order is not None
#    3186     or (sharex and p.orient == "v")
#    3187     or (sharey and p.orient == "h")
#    3188 ):
#    3189     # Sync categorical axis between facets to have the same categories
#    3190     order = p.group_names
#
# File ~\python\odev\env\lib\site-packages\seaborn\categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'genre'

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# %%
sns.distplot(df['tempo'])

# %%
sns.pairplot(df[['tempo' ,'mode', 'energy']])

# %%
sns.pairplot(df[['danceability' ,'loudness', 'liveness']])

# %%
sns.pointplot(df[['danceability' ,'loudness', 'liveness']])

# %%
sns.catplot(data=df,x = 'energy', y='instrumentalness', kind="bar")

# %%
df

# %%
genre_m1.value_counts()
# Out:
# pop                  5965
# rock                 5574
# hip_hop              2686
# trap                 2334
# contemporary         1502
# country              1008
# house                1007
# stomp_and_holler      961
# soul                  786
# indie                 780
# worship               614
# reggae                398
# jazz                  380
# r&b                   343
# punk                  340
# singer-songwriter     301
# show_tunes            290
# screamo               254
# post-grunge           195
# regional_mexican      185
# tropical              174
# Name: genres, dtype: int64

# %%
def transform(feature):
    le=LabelEncoder()
    df[feature]=le.fit_transform(df[feature])

# %%
cat_df=df.select_dtypes(include='object')
cat_df.columns
# Out:
# Index(['genres', 'subjectivity', 'polarity'], dtype='object')

# %%
for col in cat_df.columns:
    if(col != 'genres'):
        transform(col)

df
# Out:
#          danceability  energy  key  loudness  mode  speechiness  acousticness  \
# genres
# hip_hop         0.904   0.813    4    -7.105     0     0.767977      0.176352
# pop             0.774   0.838    5    -3.914     0     0.762278      0.157797
# r&b             0.664   0.758    2    -6.583     0     0.822768      0.048785
# pop             0.892   0.714    4    -6.055     0     0.782803      0.448330
# reggae          0.853   0.606    0    -4.596     1     0.718847      0.236854
# ...               ...     ...  ...       ...   ...          ...           ...
# pop             0.458   0.650    5    -6.581     1     0.653590      0.417133
# soul            0.416   0.394   11    -9.269     1     0.709345      0.716240
# r&b             0.493   0.727    1    -5.031     1     0.826147      0.295466
# rock            0.702   0.524    7   -10.710     1     0.728466      0.576194
# rock            0.639   0.461    6    -8.260     0     0.686445      0.597495
#
#          instrumentalness  liveness  valence    tempo   genres  track_pop  \
# genres
# hip_hop          0.537532  0.465860    0.810  125.461  hip_hop         69
# pop              0.630583  0.701381    0.924  143.040      pop         83
# r&b              0.000000  0.494510    0.701   99.259      r&b         25
# pop              0.351683  0.477760    0.817  100.972      pop         79
# reggae           0.000000  0.747973    0.654   94.759   reggae          2
# ...                   ...       ...      ...      ...      ...        ...
# pop              0.000000  0.542318    0.341   77.953      pop         20
# soul             0.445442  0.560647    0.131   81.988     soul          0
# r&b              0.000000  0.599304    0.289   73.259      r&b         37
# rock             0.696371  0.738846    0.265  140.089     rock         49
# rock             0.294511  0.578502    0.264  117.583     rock         40
#
#          subjectivity  polarity
# genres
# hip_hop             1         1
# pop                 1         1
# r&b                 0         0
# pop                 1         1
# reggae              1         1
# ...               ...       ...
# pop                 0         1
# soul                1         1
# r&b                 1         1
# rock                1         1
# rock                1         1
#
# [26077 rows x 15 columns]

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# %%
df.dtypes
# Out:
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# genres               object
# track_pop             int64
# subjectivity          int32
# polarity              int32
# dtype: object

# %%
X = df.drop('genres',axis=1)
Y = df.genres

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.15)
X_train,X_val,y_train,y_val=train_test_split(X_train,y_train,test_size=0.15)

# %%
from sklearn.preprocessing import StandardScaler

standard_scaler = StandardScaler().fit(X_train)

# Standard Scaler
X_train_ST = standard_scaler.transform(X_train)
X_test_ST = standard_scaler.transform(X_test)

# %%
unique = np.unique(y_train)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

rand_forest = RandomForestClassifier(random_state = 42, min_samples_split = 5)
clf = LogisticRegression(multi_class = 'ovr')

# %%
df.dtypes

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
result_ST =[]
kfold = StratifiedKFold(n_splits = 5, random_state = 1, shuffle = True)
RF_cross_val_score = cross_val_score(rand_forest, X_train_ST, y_train, cv = kfold, scoring = 'accuracy')
print('%s: %f (%f)' % ('Random Forest', RF_cross_val_score.mean(), RF_cross_val_score.std()))

# %%
kfold = StratifiedKFold(n_splits = 5, random_state = 1, shuffle = True)
RF_cross_val_score = cross_val_score(clf, X_train_ST, y_train, cv = kfold, scoring = 'accuracy')
print('%s: %f (%f)' % ('Random Forest', RF_cross_val_score.mean(), RF_cross_val_score.std()))

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(df.corr(),annot=False)

# %%
rs = np.random.RandomState(0)
df2 = pd.DataFrame(rs.rand(20,20))
corr = df2.corr()
corr.style.background_gradient(cmap='coolwarm')

# %%
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier(verbose=-1,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models

# %%
# build the lightgbm model
import lightgbm as lgb
clf = lgb.LGBMClassifier()
clf.fit(X_train_ST, y_train)
# Out:
# LGBMClassifier()

# %%
y_pred=clf.predict(X_test_ST);

# %%
print('Test set score: {:.4f}'.format(clf.score(X_test_ST, y_test)))
# Out:
# Test set score: 0.3919

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#                    precision    recall  f1-score   support
#
#      contemporary       0.29      0.14      0.19       216
#           country       0.25      0.10      0.15       147
#           hip_hop       0.40      0.45      0.42       414
#             house       0.49      0.29      0.36       140
#             indie       0.28      0.06      0.10       115
#              jazz       0.38      0.16      0.22        63
#               pop       0.38      0.52      0.44       945
#       post-grunge       0.00      0.00      0.00        20
#              punk       0.41      0.20      0.26        46
#               r&b       0.00      0.00      0.00        53
#            reggae       0.10      0.05      0.06        42
#  regional_mexican       0.54      0.48      0.51        27
#              rock       0.41      0.62      0.49       817
#           screamo       0.36      0.08      0.13        52
#        show_tunes       0.41      0.21      0.28        42
# singer-songwriter       0.18      0.05      0.08        41
#              soul       0.26      0.07      0.11       125
#  stomp_and_holler       0.23      0.11      0.15       140
#              trap       0.47      0.45      0.46       368
#          tropical       0.33      0.15      0.21        20
#           worship       0.41      0.23      0.29        79
#
#          accuracy                           0.39      3912
#         macro avg       0.31      0.21      0.23      3912
#      weighted avg       0.37      0.39      0.36      3912

# %%
preds_proba = clf.predict_proba(X_test_ST)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#                    precision    recall  f1-score   support
#
#      contemporary       0.29      0.14      0.19       216
#           country       0.25      0.10      0.15       147
#           hip_hop       0.40      0.45      0.42       414
#             house       0.49      0.29      0.36       140
#             indie       0.28      0.06      0.10       115
#              jazz       0.38      0.16      0.22        63
#               pop       0.38      0.52      0.44       945
#       post-grunge       0.00      0.00      0.00        20
#              punk       0.41      0.20      0.26        46
#               r&b       0.00      0.00      0.00        53
#            reggae       0.10      0.05      0.06        42
#  regional_mexican       0.54      0.48      0.51        27
#              rock       0.41      0.62      0.49       817
#           screamo       0.36      0.08      0.13        52
#        show_tunes       0.41      0.21      0.28        42
# singer-songwriter       0.18      0.05      0.08        41
#              soul       0.26      0.07      0.11       125
#  stomp_and_holler       0.23      0.11      0.15       140
#              trap       0.47      0.45      0.46       368
#          tropical       0.33      0.15      0.21        20
#           worship       0.41      0.23      0.29        79
#
#          accuracy                           0.39      3912
#         macro avg       0.31      0.21      0.23      3912
#      weighted avg       0.37      0.39      0.36      3912

# %%
preds_proba
# Out:
# array([[4.67561141e-03, 3.76940907e-03, 1.64014772e-02, ...,
#         2.63391530e-03, 4.20287753e-06, 8.59582323e-03],
#        [1.03373492e-01, 2.39740889e-02, 1.80098637e-02, ...,
#         5.67347361e-02, 2.12011745e-04, 1.72023221e-02],
#        [3.42902776e-02, 6.75065549e-03, 1.12400529e-02, ...,
#         6.33135784e-03, 2.68402671e-05, 2.51677858e-03],
#        ...,
#        [7.74160629e-03, 1.07530246e-03, 7.23401843e-02, ...,
#         3.34088126e-02, 3.24831524e-06, 2.63311126e-04],
#        [1.58221941e-01, 3.22930098e-02, 1.34010814e-01, ...,
#         4.15040365e-02, 2.38620628e-04, 2.72051490e-03],
#        [2.67675123e-03, 2.92207096e-01, 7.77919886e-03, ...,
#         1.41650288e-03, 5.02612542e-05, 2.67536278e-02]])

# %%
preds_proba = clf.predict_proba(X_test_ST)

# %%
def top5score(preds, ground_truth, model):
    if not len(preds) == len(ground_truth):
        raise exception('Shape Mismatch')
    
    mdfd_pred = []
    for i in range(len(preds)):
        preds_classes = model.classes_[preds[i].argsort()[::-1][:3]]
        print(preds_classes)
        if ground_truth[i] in preds_classes :
            mdfd_pred.append(ground_truth[i])
        else:
            mdfd_pred.append(preds_classes[0])
    return mdfd_pred

# %%
mdfd_pred = top5score(preds_proba, y_test.values, clf)
# Out:
# ['pop' 'stomp_and_holler' 'indie']
# ['pop' 'rock' 'contemporary']
# ['regional_mexican' 'pop' 'rock']
# ['indie' 'rock' 'country']
# ['rock' 'country' 'pop']
# ['country' 'rock' 'pop']
# ['pop' 'contemporary' 'trap']
# ['rock' 'pop' 'hip_hop']
# ['trap' 'pop' 'hip_hop']
# ['pop' 'rock' 'worship']
# ['rock' 'pop' 'contemporary']
# ['singer-songwriter' 'pop' 'rock']
# ['pop' 'house' 'hip_hop']
# ['rock' 'pop' 'stomp_and_holler']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'country']
# ['rock' 'singer-songwriter' 'pop']
# ['rock' 'pop' 'punk']
# ['house' 'pop' 'trap']
# ['pop' 'contemporary' 'trap']
# ['rock' 'pop' 'punk']
# ['rock' 'pop' 'house']
# ['pop' 'rock' 'trap']
# ['contemporary' 'pop' 'hip_hop']
# ['pop' 'rock' 'contemporary']
# ['pop' 'indie' 'rock']
# ['pop' 'stomp_and_holler' 'rock']
# ['country' 'rock' 'pop']
# ['hip_hop' 'pop' 'contemporary']
# ['hip_hop' 'pop' 'rock']
# ['trap' 'hip_hop' 'pop']
# ['indie' 'rock' 'pop']
# ['pop' 'rock' 'hip_hop']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'country']
# ['pop' 'contemporary' 'trap']
# ['trap' 'pop' 'hip_hop']
# ['pop' 'rock' 'contemporary']
# ['trap' 'hip_hop' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'house' 'rock']
# ['hip_hop' 'trap' 'pop']
# ['regional_mexican' 'pop' 'soul']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'stomp_and_holler']
# ['contemporary' 'pop' 'rock']
# ['pop' 'trap' 'contemporary']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'house']
# ['pop' 'rock' 'trap']
# ['house' 'pop' 'rock']
# ['rock' 'pop' 'worship']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'contemporary' 'rock']
# ['rock' 'country' 'soul']
# ['pop' 'trap' 'hip_hop']
# ['pop' 'stomp_and_holler' 'rock']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'country']
# ['rock' 'contemporary' 'pop']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'soul']
# ['hip_hop' 'pop' 'trap']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'house']
# ['rock' 'stomp_and_holler' 'pop']
# ['pop' 'trap' 'contemporary']
# ['hip_hop' 'trap' 'contemporary']
# ['rock' 'pop' 'indie']
# ['house' 'pop' 'hip_hop']
# ['rock' 'pop' 'house']
# ['pop' 'contemporary' 'rock']
# ['rock' 'soul' 'pop']
# ['rock' 'pop' 'stomp_and_holler']
# ['trap' 'pop' 'hip_hop']
# ['pop' 'trap' 'hip_hop']
# ['pop' 'rock' 'country']
# ['trap' 'hip_hop' 'pop']
# ['house' 'hip_hop' 'trap']
# ['rock' 'pop' 'contemporary']
# ['jazz' 'stomp_and_holler' 'pop']
# ['stomp_and_holler' 'rock' 'pop']
# ['rock' 'pop' 'post-grunge']
# ['trap' 'hip_hop' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'stomp_and_holler']
# ['hip_hop' 'contemporary' 'pop']
# ['pop' 'house' 'rock']
# ['stomp_and_holler' 'rock' 'pop']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'hip_hop']
# ['hip_hop' 'pop' 'soul']
# ['hip_hop' 'trap' 'pop']
# ['show_tunes' 'pop' 'contemporary']
# ['rock' 'pop' 'trap']
# ['pop' 'contemporary' 'rock']
# ['rock' 'pop' 'contemporary']
# ['country' 'rock' 'pop']
# ['hip_hop' 'house' 'pop']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'contemporary']
# ['pop' 'rock' 'singer-songwriter']
# ['trap' 'pop' 'hip_hop']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'post-grunge']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'worship']
# ['rock' 'pop' 'country']
# ['contemporary' 'pop' 'r&b']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'country']
# ['pop' 'contemporary' 'hip_hop']
# ['pop' 'rock' 'country']
# ['pop' 'rock' 'country']
# ['pop' 'contemporary' 'rock']
# ['pop' 'trap' 'rock']
# ['country' 'rock' 'pop']
# ['pop' 'house' 'rock']
# ['rock' 'pop' 'country']
# ['hip_hop' 'pop' 'trap']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'house' 'indie']
# ['pop' 'rock' 'contemporary']
# ['stomp_and_holler' 'rock' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'contemporary']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'contemporary' 'pop']
# ['pop' 'rock' 'house']
# ['rock' 'pop' 'contemporary']
# ['post-grunge' 'pop' 'rock']
# ['pop' 'rock' 'screamo']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'punk']
# ['hip_hop' 'trap' 'contemporary']
# ['contemporary' 'indie' 'rock']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'indie']
# ['hip_hop' 'rock' 'pop']
# ['rock' 'pop' 'punk']
# ['rock' 'pop' 'house']
# ['pop' 'rock' 'soul']
# ['rock' 'jazz' 'pop']
# ['hip_hop' 'trap' 'house']
# ['pop' 'trap' 'hip_hop']
# ['hip_hop' 'pop' 'trap']
# ['pop' 'rock' 'stomp_and_holler']
# ['pop' 'hip_hop' 'contemporary']
# ['house' 'pop' 'rock']
# ['hip_hop' 'trap' 'contemporary']
# ['rock' 'pop' 'hip_hop']
# ['pop' 'rock' 'country']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'rock' 'house']
# ['rock' 'pop' 'house']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'pop' 'country']
# ['trap' 'pop' 'hip_hop']
# ['rock' 'pop' 'punk']
# ['pop' 'rock' 'soul']
# ['pop' 'hip_hop' 'house']
# ['pop' 'rock' 'worship']
# ['pop' 'rock' 'house']
# ['pop' 'rock' 'country']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'contemporary' 'rock']
# ['jazz' 'stomp_and_holler' 'pop']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'indie']
# ['trap' 'pop' 'hip_hop']
# ['rock' 'post-grunge' 'pop']
# ['pop' 'rock' 'indie']
# ['contemporary' 'rock' 'hip_hop']
# ['rock' 'screamo' 'pop']
# ['trap' 'hip_hop' 'contemporary']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'show_tunes']
# ['pop' 'rock' 'trap']
# ['pop' 'rock' 'trap']
# ['house' 'pop' 'soul']
# ['trap' 'hip_hop' 'reggae']
# ['rock' 'pop' 'trap']
# ['rock' 'soul' 'pop']
# ['rock' 'soul' 'pop']
# ['pop' 'soul' 'rock']
# ['hip_hop' 'trap' 'pop']
# ['hip_hop' 'house' 'pop']
# ['rock' 'country' 'soul']
# ['rock' 'pop' 'country']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'post-grunge' 'pop']
# ['pop' 'rock' 'stomp_and_holler']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'jazz']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'contemporary' 'rock']
# ['show_tunes' 'singer-songwriter' 'pop']
# ['pop' 'hip_hop' 'trap']
# ['rock' 'pop' 'country']
# ['trap' 'pop' 'hip_hop']
# ['pop' 'soul' 'rock']
# ['contemporary' 'pop' 'hip_hop']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'contemporary']
# ['pop' 'hip_hop' 'trap']
# ['pop' 'rock' 'contemporary']
# ['hip_hop' 'trap' 'contemporary']
# ['rock' 'pop' 'singer-songwriter']
# ['country' 'rock' 'pop']
# ['pop' 'rock' 'soul']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'country']
# ['pop' 'hip_hop' 'contemporary']
# ['hip_hop' 'pop' 'trap']
# ['pop' 'contemporary' 'hip_hop']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'hip_hop']
# ['country' 'pop' 'rock']
# ['trap' 'pop' 'contemporary']
# ['rock' 'pop' 'soul']
# ['house' 'pop' 'hip_hop']
# ['rock' 'pop' 'screamo']
# ['show_tunes' 'hip_hop' 'rock']
# ['rock' 'screamo' 'pop']
# ['rock' 'pop' 'punk']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'country']
# ['house' 'pop' 'rock']
# ['pop' 'rock' 'hip_hop']
# ['punk' 'rock' 'pop']
# ['hip_hop' 'pop' 'trap']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'contemporary' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['house' 'pop' 'hip_hop']
# ['pop' 'hip_hop' 'rock']
# ['pop' 'rock' 'country']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'country']
# ['pop' 'hip_hop' 'contemporary']
# ['rock' 'pop' 'indie']
# ['pop' 'country' 'rock']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'hip_hop' 'rock']
# ['hip_hop' 'trap' 'contemporary']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'pop' 'country']
# ['soul' 'rock' 'pop']
# ['house' 'pop' 'rock']
# ['rock' 'pop' 'soul']
# ['pop' 'house' 'hip_hop']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'stomp_and_holler']
# ['trap' 'regional_mexican' 'pop']
# ['pop' 'rock' 'hip_hop']
# ['pop' 'rock' 'trap']
# ['rock' 'pop' 'soul']
# ['hip_hop' 'trap' 'pop']
# ['stomp_and_holler' 'rock' 'pop']
# ['pop' 'hip_hop' 'soul']
# ['pop' 'rock' 'worship']
# ['pop' 'contemporary' 'rock']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'stomp_and_holler' 'hip_hop']
# ['hip_hop' 'contemporary' 'pop']
# ['rock' 'pop' 'hip_hop']
# ['post-grunge' 'rock' 'pop']
# ['hip_hop' 'pop' 'contemporary']
# ['rock' 'stomp_and_holler' 'pop']
# ['contemporary' 'pop' 'hip_hop']
# ['rock' 'pop' 'country']
# ['pop' 'contemporary' 'rock']
# ['pop' 'trap' 'reggae']
# ['hip_hop' 'pop' 'rock']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'pop' 'country']
# ['pop' 'stomp_and_holler' 'indie']
# ['hip_hop' 'contemporary' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'rock' 'contemporary']
# ['pop' 'hip_hop' 'rock']
# ['pop' 'stomp_and_holler' 'rock']
# ['pop' 'rock' 'stomp_and_holler']
# ['trap' 'contemporary' 'pop']
# ['rock' 'soul' 'country']
# ['pop' 'contemporary' 'hip_hop']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'post-grunge']
# ['pop' 'trap' 'hip_hop']
# ['trap' 'hip_hop' 'contemporary']
# ['trap' 'hip_hop' 'pop']
# ['punk' 'rock' 'pop']
# ['pop' 'trap' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'contemporary' 'trap']
# ['pop' 'rock' 'contemporary']
# ['hip_hop' 'trap' 'reggae']
# ['pop' 'rock' 'country']
# ['pop' 'contemporary' 'rock']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'punk']
# ['hip_hop' 'trap' 'contemporary']
# ['pop' 'contemporary' 'hip_hop']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'country']
# ['pop' 'trap' 'hip_hop']
# ['worship' 'rock' 'pop']
# ['pop' 'rock' 'post-grunge']
# ['punk' 'trap' 'hip_hop']
# ['reggae' 'country' 'pop']
# ['country' 'rock' 'pop']
# ['pop' 'rock' 'house']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'punk']
# ['pop' 'rock' 'house']
# ['jazz' 'stomp_and_holler' 'rock']
# ['rock' 'country' 'pop']
# ['pop' 'rock' 'contemporary']
# ['trap' 'pop' 'contemporary']
# ['pop' 'trap' 'hip_hop']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'hip_hop' 'house']
# ['pop' 'rock' 'hip_hop']
# ['hip_hop' 'pop' 'rock']
# ['rock' 'country' 'worship']
# ['hip_hop' 'pop' 'trap']
# ['trap' 'hip_hop' 'pop']
# ['screamo' 'pop' 'rock']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'trap' 'rock']
# ['hip_hop' 'pop' 'contemporary']
# ['indie' 'rock' 'pop']
# ['punk' 'trap' 'hip_hop']
# ['pop' 'trap' 'hip_hop']
# ['stomp_and_holler' 'rock' 'pop']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'tropical']
# ['rock' 'pop' 'soul']
# ['worship' 'rock' 'pop']
# ['pop' 'trap' 'hip_hop']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'contemporary']
# ['pop' 'contemporary' 'hip_hop']
# ['hip_hop' 'trap' 'pop']
# ['reggae' 'pop' 'trap']
# ['pop' 'rock' 'post-grunge']
# ['hip_hop' 'trap' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'stomp_and_holler']
# ['soul' 'pop' 'rock']
# ['house' 'pop' 'rock']
# ['house' 'rock' 'pop']
# ['pop' 'rock' 'stomp_and_holler']
# ['hip_hop' 'pop' 'contemporary']
# ['pop' 'rock' 'trap']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'trap' 'house']
# ['trap' 'contemporary' 'pop']
# ['rock' 'indie' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'hip_hop']
# ['pop' 'rock' 'house']
# ['pop' 'hip_hop' 'contemporary']
# ['pop' 'contemporary' 'hip_hop']
# ['pop' 'rock' 'soul']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'trap']
# ['rock' 'pop' 'indie']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'indie' 'rock']
# ['pop' 'rock' 'hip_hop']
# ['pop' 'rock' 'indie']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'hip_hop']
# ['jazz' 'pop' 'rock']
# ['show_tunes' 'pop' 'rock']
# ['rock' 'pop' 'indie']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'punk']
# ['pop' 'rock' 'country']
# ['rock' 'punk' 'pop']
# ['hip_hop' 'trap' 'contemporary']
# ['rock' 'pop' 'hip_hop']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'house']
# ['rock' 'pop' 'stomp_and_holler']
# ['hip_hop' 'trap' 'contemporary']
# ['pop' 'rock' 'hip_hop']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'country' 'pop']
# ['worship' 'rock' 'pop']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'rock' 'reggae']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'house']
# ['rock' 'pop' 'worship']
# ['rock' 'pop' 'punk']
# ['pop' 'stomp_and_holler' 'rock']
# ['soul' 'pop' 'rock']
# ['country' 'rock' 'pop']
# ['pop' 'rock' 'worship']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'country']
# ['contemporary' 'jazz' 'rock']
# ['pop' 'hip_hop' 'house']
# ['pop' 'trap' 'hip_hop']
# ['pop' 'rock' 'stomp_and_holler']
# ['pop' 'worship' 'rock']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'singer-songwriter']
# ['rock' 'pop' 'contemporary']
# ['worship' 'pop' 'rock']
# ['rock' 'pop' 'soul']
# ['trap' 'pop' 'rock']
# ['pop' 'rock' 'hip_hop']
# ['pop' 'rock' 'hip_hop']
# ['hip_hop' 'soul' 'contemporary']
# ['rock' 'pop' 'country']
# ['pop' 'trap' 'hip_hop']
# ['house' 'pop' 'rock']
# ['rock' 'pop' 'post-grunge']
# ['pop' 'worship' 'rock']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'country']
# ['hip_hop' 'pop' 'rock']
# ['pop' 'contemporary' 'rock']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'indie' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['contemporary' 'pop' 'hip_hop']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'country']
# ['house' 'pop' 'hip_hop']
# ['pop' 'rock' 'indie']
# ['pop' 'rock' 'house']
# ['hip_hop' 'trap' 'reggae']
# ['pop' 'country' 'rock']
# ['pop' 'hip_hop' 'contemporary']
# ['rock' 'pop' 'hip_hop']
# ['hip_hop' 'pop' 'contemporary']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'country']
# ['trap' 'hip_hop' 'pop']
# ['regional_mexican' 'rock' 'pop']
# ['rock' 'hip_hop' 'contemporary']
# ['pop' 'rock' 'punk']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'pop' 'country']
# ['pop' 'contemporary' 'trap']
# ['hip_hop' 'trap' 'pop']
# ['contemporary' 'hip_hop' 'pop']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'hip_hop']
# ['house' 'pop' 'trap']
# ['rock' 'pop' 'contemporary']
# ['pop' 'rock' 'soul']
# ['rock' 'jazz' 'regional_mexican']
# ['pop' 'rock' 'indie']
# ['singer-songwriter' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'house']
# ['hip_hop' 'pop' 'trap']
# ['pop' 'trap' 'hip_hop']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'house']
# ['rock' 'pop' 'soul']
# ['regional_mexican' 'pop' 'rock']
# ['pop' 'rock' 'house']
# ['pop' 'rock' 'contemporary']
# ['house' 'pop' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'hip_hop']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'pop' 'soul']
# ['reggae' 'hip_hop' 'trap']
# ['rock' 'pop' 'hip_hop']
# ['pop' 'rock' 'worship']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'punk' 'pop']
# ['pop' 'house' 'rock']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'country']
# ['pop' 'rock' 'hip_hop']
# ['trap' 'hip_hop' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'worship']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'singer-songwriter']
# ['regional_mexican' 'pop' 'soul']
# ['rock' 'pop' 'soul']
# ['contemporary' 'pop' 'hip_hop']
# ['rock' 'contemporary' 'pop']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'rock' 'hip_hop']
# ['house' 'pop' 'rock']
# ['pop' 'contemporary' 'hip_hop']
# ['rock' 'pop' 'punk']
# ['rock' 'pop' 'country']
# ['hip_hop' 'trap' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'house' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'contemporary']
# ['pop' 'rock' 'trap']
# ['pop' 'trap' 'hip_hop']
# ['hip_hop' 'trap' 'contemporary']
# ['pop' 'rock' 'hip_hop']
# ['pop' 'rock' 'country']
# ['trap' 'hip_hop' 'pop']
# ['hip_hop' 'contemporary' 'pop']
# ['jazz' 'stomp_and_holler' 'rock']
# ['rock' 'pop' 'country']
# ['trap' 'hip_hop' 'pop']
# ['soul' 'rock' 'pop']
# ['pop' 'stomp_and_holler' 'rock']
# ['rock' 'stomp_and_holler' 'pop']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'hip_hop']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'country']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'soul']
# ['pop' 'rock' 'worship']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'country' 'worship']
# ['rock' 'pop' 'hip_hop']
# ['reggae' 'rock' 'pop']
# ['pop' 'contemporary' 'hip_hop']
# ['rock' 'pop' 'punk']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'indie']
# ['pop' 'rock' 'house']
# ['pop' 'rock' 'country']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'pop' 'country']
# ['rock' 'post-grunge' 'pop']
# ['pop' 'contemporary' 'rock']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'stomp_and_holler' 'pop']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'worship']
# ['trap' 'hip_hop' 'pop']
# ['contemporary' 'pop' 'rock']
# ['hip_hop' 'pop' 'contemporary']
# ['pop' 'indie' 'rock']
# ['country' 'rock' 'pop']
# ['rock' 'pop' 'soul']
# ['pop' 'rock' 'house']
# ['indie' 'rock' 'pop']
# ['pop' 'rock' 'indie']
# ['hip_hop' 'trap' 'contemporary']
# ['rock' 'country' 'hip_hop']
# ['contemporary' 'pop' 'hip_hop']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'trap' 'rock']
# ['pop' 'indie' 'stomp_and_holler']
# ['pop' 'rock' 'country']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'pop' 'punk']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'rock' 'stomp_and_holler']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'trap' 'hip_hop']
# ['hip_hop' 'contemporary' 'pop']
# ['rock' 'pop' 'stomp_and_holler']
# ['country' 'rock' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['hip_hop' 'pop' 'trap']
# ['worship' 'rock' 'pop']
# ['rock' 'pop' 'indie']
# ['country' 'rock' 'pop']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'pop' 'hip_hop']
# ['hip_hop' 'pop' 'rock']
# ['pop' 'rock' 'country']
# ['rock' 'post-grunge' 'pop']
# ['house' 'pop' 'trap']
# ['contemporary' 'soul' 'pop']
# ['hip_hop' 'trap' 'contemporary']
# ['pop' 'rock' 'contemporary']
# ['hip_hop' 'trap' 'regional_mexican']
# ['pop' 'rock' 'country']
# ['rock' 'worship' 'stomp_and_holler']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'house']
# ['pop' 'rock' 'house']
# ['contemporary' 'pop' 'rock']
# ['rock' 'pop' 'contemporary']
# ['rock' 'pop' 'soul']
# ['house' 'pop' 'soul']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'house']
# ['pop' 'hip_hop' 'contemporary']
# ['pop' 'trap' 'r&b']
# ['rock' 'pop' 'punk']
# ['rock' 'pop' 'hip_hop']
# ['house' 'pop' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'soul' 'pop']
# ['pop' 'trap' 'house']
# ['rock' 'stomp_and_holler' 'pop']
# ['rock' 'post-grunge' 'pop']
# ['pop' 'rock' 'contemporary']
# ['trap' 'hip_hop' 'pop']
# ['show_tunes' 'rock' 'contemporary']
# ['rock' 'pop' 'tropical']
# ['house' 'trap' 'pop']
# ['pop' 'contemporary' 'house']
# ['house' 'rock' 'hip_hop']
# ['hip_hop' 'trap' 'reggae']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'screamo' 'pop']
# ['country' 'pop' 'rock']
# ['hip_hop' 'pop' 'trap']
# ['hip_hop' 'trap' 'pop']
# ['hip_hop' 'pop' 'contemporary']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'contemporary']
# ['jazz' 'pop' 'rock']
# ['rock' 'stomp_and_holler' 'pop']
# ['stomp_and_holler' 'rock' 'pop']
# ['stomp_and_holler' 'rock' 'pop']
# ['hip_hop' 'contemporary' 'trap']
# ['regional_mexican' 'pop' 'hip_hop']
# ['trap' 'pop' 'hip_hop']
# ['pop' 'rock' 'hip_hop']
# ['pop' 'hip_hop' 'rock']
# ['pop' 'hip_hop' 'trap']
# ['trap' 'pop' 'hip_hop']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'stomp_and_holler' 'pop']
# ['pop' 'house' 'hip_hop']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'rock' 'contemporary']
# ['indie' 'pop' 'rock']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'indie' 'pop']
# ['hip_hop' 'reggae' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'soul']
# ['country' 'rock' 'pop']
# ['contemporary' 'soul' 'pop']
# ['rock' 'punk' 'pop']
# ['trap' 'pop' 'contemporary']
# ['rock' 'pop' 'stomp_and_holler']
# ['hip_hop' 'pop' 'contemporary']
# ['rock' 'pop' 'post-grunge']
# ['stomp_and_holler' 'pop' 'rock']
# ['pop' 'trap' 'contemporary']
# ['pop' 'rock' 'house']
# ['country' 'rock' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'hip_hop' 'contemporary']
# ['contemporary' 'pop' 'hip_hop']
# ['rock' 'pop' 'indie']
# ['pop' 'rock' 'hip_hop']
# ['worship' 'rock' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['stomp_and_holler' 'pop' 'rock']
# ['rock' 'pop' 'house']
# ['pop' 'contemporary' 'rock']
# ['pop' 'rock' 'jazz']
# ['pop' 'trap' 'hip_hop']
# ['pop' 'trap' 'hip_hop']
# ['hip_hop' 'trap' 'contemporary']
# ['pop' 'contemporary' 'hip_hop']
# ['pop' 'rock' 'house']
# ['rock' 'country' 'pop']
# ['pop' 'stomp_and_holler' 'rock']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'contemporary' 'rock']
# ['pop' 'hip_hop' 'contemporary']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'punk']
# ['pop' 'house' 'trap']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'stomp_and_holler' 'pop']
# ['rock' 'pop' 'hip_hop']
# ['hip_hop' 'contemporary' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'house']
# ['rock' 'pop' 'country']
# ['trap' 'pop' 'hip_hop']
# ['rock' 'pop' 'stomp_and_holler']
# ['indie' 'pop' 'contemporary']
# ['house' 'pop' 'rock']
# ['jazz' 'rock' 'pop']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'rock' 'soul']
# ['hip_hop' 'pop' 'rock']
# ['rock' 'pop' 'indie']
# ['pop' 'stomp_and_holler' 'trap']
# ['pop' 'rock' 'contemporary']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'hip_hop' 'rock']
# ['pop' 'country' 'rock']
# ['pop' 'stomp_and_holler' 'contemporary']
# ['rock' 'country' 'pop']
# ['trap' 'pop' 'hip_hop']
# ['pop' 'contemporary' 'rock']
# ['house' 'pop' 'contemporary']
# ['pop' 'rock' 'country']
# ['pop' 'rock' 'stomp_and_holler']
# ['trap' 'pop' 'rock']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'stomp_and_holler']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'trap' 'rock']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'pop' 'soul']
# ['pop' 'trap' 'rock']
# ['pop' 'rock' 'soul']
# ['rock' 'singer-songwriter' 'pop']
# ['rock' 'worship' 'singer-songwriter']
# ['pop' 'rock' 'house']
# ['pop' 'contemporary' 'rock']
# ['pop' 'trap' 'contemporary']
# ['rock' 'pop' 'indie']
# ['trap' 'hip_hop' 'pop']
# ['show_tunes' 'pop' 'rock']
# ['pop' 'rock' 'stomp_and_holler']
# ['hip_hop' 'trap' 'contemporary']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'post-grunge']
# ['pop' 'rock' 'worship']
# ['pop' 'rock' 'contemporary']
# ['pop' 'house' 'rock']
# ['hip_hop' 'contemporary' 'trap']
# ['hip_hop' 'trap' 'contemporary']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'worship']
# ['pop' 'show_tunes' 'indie']
# ['rock' 'pop' 'house']
# ['hip_hop' 'trap' 'pop']
# ['contemporary' 'pop' 'trap']
# ['pop' 'rock' 'country']
# ['stomp_and_holler' 'pop' 'rock']
# ['pop' 'rock' 'indie']
# ['rock' 'pop' 'soul']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'hip_hop']
# ['hip_hop' 'trap' 'contemporary']
# ['stomp_and_holler' 'pop' 'rock']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'stomp_and_holler']
# ['house' 'pop' 'contemporary']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'hip_hop']
# ['jazz' 'rock' 'pop']
# ['r&b' 'soul' 'contemporary']
# ['hip_hop' 'pop' 'screamo']
# ['pop' 'rock' 'contemporary']
# ['contemporary' 'pop' 'hip_hop']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'worship']
# ['pop' 'rock' 'house']
# ['rock' 'stomp_and_holler' 'pop']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'screamo' 'pop']
# ['rock' 'pop' 'worship']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'contemporary']
# ['hip_hop' 'contemporary' 'reggae']
# ['rock' 'pop' 'soul']
# ['pop' 'rock' 'country']
# ['trap' 'hip_hop' 'contemporary']
# ['rock' 'country' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'indie']
# ['trap' 'rock' 'pop']
# ['pop' 'rock' 'soul']
# ['rock' 'pop' 'country']
# ['house' 'pop' 'rock']
# ['hip_hop' 'pop' 'rock']
# ['screamo' 'rock' 'pop']
# ['pop' 'rock' 'house']
# ['pop' 'rock' 'r&b']
# ['hip_hop' 'pop' 'trap']
# ['pop' 'rock' 'country']
# ['rock' 'country' 'stomp_and_holler']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'punk' 'pop']
# ['soul' 'house' 'hip_hop']
# ['pop' 'rock' 'contemporary']
# ['pop' 'house' 'rock']
# ['regional_mexican' 'rock' 'trap']
# ['rock' 'pop' 'worship']
# ['hip_hop' 'pop' 'contemporary']
# ['rock' 'pop' 'punk']
# ['trap' 'pop' 'reggae']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'contemporary' 'rock']
# ['pop' 'rock' 'screamo']
# ['pop' 'stomp_and_holler' 'rock']
# ['hip_hop' 'pop' 'contemporary']
# ['pop' 'rock' 'contemporary']
# ['trap' 'show_tunes' 'hip_hop']
# ['pop' 'house' 'soul']
# ['rock' 'pop' 'soul']
# ['regional_mexican' 'pop' 'rock']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'hip_hop' 'regional_mexican']
# ['rock' 'pop' 'worship']
# ['rock' 'pop' 'soul']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'stomp_and_holler']
# ['house' 'pop' 'rock']
# ['pop' 'rock' 'indie']
# ['pop' 'hip_hop' 'rock']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'hip_hop' 'contemporary']
# ['pop' 'hip_hop' 'rock']
# ['rock' 'pop' 'indie']
# ['rock' 'stomp_and_holler' 'pop']
# ['rock' 'country' 'pop']
# ['rock' 'pop' 'contemporary']
# ['worship' 'rock' 'pop']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'worship']
# ['tropical' 'rock' 'soul']
# ['pop' 'rock' 'house']
# ['rock' 'pop' 'country']
# ['pop' 'house' 'hip_hop']
# ['pop' 'hip_hop' 'trap']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'tropical' 'country']
# ['pop' 'rock' 'stomp_and_holler']
# ['hip_hop' 'pop' 'trap']
# ['pop' 'trap' 'contemporary']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'house']
# ['post-grunge' 'rock' 'pop']
# ['rock' 'pop' 'worship']
# ['hip_hop' 'contemporary' 'pop']
# ['rock' 'pop' 'country']
# ['reggae' 'pop' 'contemporary']
# ['rock' 'pop' 'contemporary']
# ['pop' 'house' 'rock']
# ['pop' 'contemporary' 'rock']
# ['contemporary' 'pop' 'hip_hop']
# ['hip_hop' 'pop' 'contemporary']
# ['pop' 'rock' 'indie']
# ['jazz' 'pop' 'indie']
# ['rock' 'indie' 'pop']
# ['rock' 'pop' 'punk']
# ['pop' 'hip_hop' 'rock']
# ['contemporary' 'pop' 'rock']
# ['pop' 'contemporary' 'rock']
# ['rock' 'pop' 'singer-songwriter']
# ['pop' 'stomp_and_holler' 'indie']
# ['pop' 'trap' 'contemporary']
# ['singer-songwriter' 'jazz' 'rock']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'contemporary']
# ['hip_hop' 'pop' 'rock']
# ['rock' 'pop' 'post-grunge']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'stomp_and_holler']
# ['hip_hop' 'trap' 'pop']
# ['trap' 'pop' 'hip_hop']
# ['stomp_and_holler' 'rock' 'pop']
# ['hip_hop' 'pop' 'contemporary']
# ['pop' 'rock' 'trap']
# ['regional_mexican' 'pop' 'rock']
# ['punk' 'rock' 'screamo']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'stomp_and_holler' 'pop']
# ['rock' 'pop' 'country']
# ['punk' 'rock' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'house']
# ['pop' 'rock' 'house']
# ['jazz' 'pop' 'rock']
# ['rock' 'pop' 'soul']
# ['pop' 'rock' 'country']
# ['rock' 'country' 'pop']
# ['rock' 'pop' 'country']
# ['rock' 'punk' 'pop']
# ['stomp_and_holler' 'singer-songwriter' 'rock']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'country']
# ['pop' 'house' 'hip_hop']
# ['pop' 'rock' 'post-grunge']
# ['rock' 'pop' 'indie']
# ['rock' 'country' 'pop']
# ['rock' 'pop' 'contemporary']
# ['hip_hop' 'contemporary' 'trap']
# ['hip_hop' 'pop' 'trap']
# ['trap' 'hip_hop' 'contemporary']
# ['rock' 'pop' 'country']
# ['pop' 'contemporary' 'hip_hop']
# ['hip_hop' 'trap' 'pop']
# ['r&b' 'pop' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'trap' 'contemporary']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'indie']
# ['pop' 'rock' 'country']
# ['trap' 'pop' 'hip_hop']
# ['rock' 'pop' 'country']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'country' 'pop']
# ['pop' 'rock' 'indie']
# ['hip_hop' 'soul' 'contemporary']
# ['rock' 'pop' 'country']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'contemporary' 'hip_hop']
# ['rock' 'pop' 'soul']
# ['pop' 'trap' 'hip_hop']
# ['pop' 'jazz' 'rock']
# ['pop' 'rock' 'hip_hop']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'soul' 'hip_hop']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'country']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'stomp_and_holler' 'pop']
# ['rock' 'pop' 'contemporary']
# ['rock' 'pop' 'trap']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'contemporary']
# ['pop' 'rock' 'worship']
# ['pop' 'rock' 'country']
# ['hip_hop' 'pop' 'trap']
# ['jazz' 'rock' 'pop']
# ['rock' 'pop' 'indie']
# ['contemporary' 'pop' 'trap']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'worship']
# ['hip_hop' 'pop' 'house']
# ['pop' 'rock' 'house']
# ['hip_hop' 'pop' 'house']
# ['stomp_and_holler' 'jazz' 'rock']
# ['rock' 'pop' 'contemporary']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'worship']
# ['hip_hop' 'trap' 'pop']
# ['contemporary' 'pop' 'hip_hop']
# ['rock' 'reggae' 'pop']
# ['country' 'rock' 'singer-songwriter']
# ['pop' 'rock' 'stomp_and_holler']
# ['pop' 'rock' 'house']
# ['rock' 'pop' 'stomp_and_holler']
# ['singer-songwriter' 'rock' 'pop']
# ['soul' 'rock' 'pop']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'house']
# ['pop' 'indie' 'contemporary']
# ['trap' 'rock' 'pop']
# ['contemporary' 'reggae' 'pop']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'punk']
# ['rock' 'pop' 'soul']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'jazz']
# ['contemporary' 'trap' 'hip_hop']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'indie']
# ['trap' 'hip_hop' 'contemporary']
# ['stomp_and_holler' 'rock' 'pop']
# ['rock' 'stomp_and_holler' 'pop']
# ['contemporary' 'trap' 'hip_hop']
# ['pop' 'country' 'rock']
# ['pop' 'trap' 'hip_hop']
# ['house' 'pop' 'hip_hop']
# ['rock' 'pop' 'trap']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'stomp_and_holler']
# ['contemporary' 'pop' 'rock']
# ['hip_hop' 'contemporary' 'pop']
# ['worship' 'pop' 'rock']
# ['pop' 'contemporary' 'house']
# ['rock' 'pop' 'country']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'country']
# ['stomp_and_holler' 'rock' 'pop']
# ['rock' 'pop' 'contemporary']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'hip_hop']
# ['contemporary' 'pop' 'hip_hop']
# ['rock' 'pop' 'country']
# ['rock' 'soul' 'pop']
# ['pop' 'contemporary' 'house']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'country']
# ['pop' 'hip_hop' 'rock']
# ['pop' 'contemporary' 'rock']
# ['pop' 'trap' 'hip_hop']
# ['hip_hop' 'pop' 'trap']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'pop' 'screamo']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'pop' 'country']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'trap' 'contemporary']
# ['contemporary' 'hip_hop' 'pop']
# ['rock' 'pop' 'soul']
# ['pop' 'rock' 'stomp_and_holler']
# ['pop' 'house' 'rock']
# ['indie' 'rock' 'pop']
# ['pop' 'rock' 'house']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'worship']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'worship']
# ['reggae' 'contemporary' 'soul']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'pop' 'punk']
# ['rock' 'pop' 'house']
# ['trap' 'reggae' 'pop']
# ['pop' 'soul' 'rock']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'punk' 'pop']
# ['rock' 'pop' 'stomp_and_holler']
# ['country' 'rock' 'pop']
# ['pop' 'rock' 'trap']
# ['rock' 'pop' 'worship']
# ['punk' 'rock' 'pop']
# ['hip_hop' 'trap' 'contemporary']
# ['worship' 'rock' 'country']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'country']
# ['pop' 'contemporary' 'trap']
# ['hip_hop' 'trap' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'house' 'contemporary']
# ['hip_hop' 'trap' 'contemporary']
# ['pop' 'rock' 'worship']
# ['pop' 'rock' 'stomp_and_holler']
# ['hip_hop' 'trap' 'pop']
# ['hip_hop' 'pop' 'trap']
# ['pop' 'rock' 'contemporary']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'stomp_and_holler']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'hip_hop' 'rock']
# ['rock' 'pop' 'show_tunes']
# ['pop' 'stomp_and_holler' 'rock']
# ['pop' 'hip_hop' 'rock']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'soul']
# ['trap' 'hip_hop' 'contemporary']
# ['hip_hop' 'trap' 'contemporary']
# ['pop' 'hip_hop' 'trap']
# ['pop' 'jazz' 'hip_hop']
# ['hip_hop' 'reggae' 'trap']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'stomp_and_holler']
# ['stomp_and_holler' 'pop' 'indie']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'contemporary']
# ['stomp_and_holler' 'pop' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'rock' 'country']
# ['pop' 'house' 'rock']
# ['stomp_and_holler' 'rock' 'pop']
# ['show_tunes' 'contemporary' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'country' 'pop']
# ['pop' 'rock' 'worship']
# ['pop' 'rock' 'trap']
# ['pop' 'contemporary' 'rock']
# ['pop' 'hip_hop' 'trap']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'trap' 'house']
# ['trap' 'pop' 'hip_hop']
# ['rock' 'pop' 'worship']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'indie']
# ['pop' 'rock' 'country']
# ['house' 'pop' 'hip_hop']
# ['trap' 'pop' 'hip_hop']
# ['country' 'rock' 'pop']
# ['pop' 'rock' 'stomp_and_holler']
# ['trap' 'hip_hop' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['house' 'rock' 'pop']
# ['hip_hop' 'reggae' 'trap']
# ['pop' 'hip_hop' 'rock']
# ['contemporary' 'pop' 'rock']
# ['pop' 'trap' 'house']
# ['contemporary' 'pop' 'rock']
# ['pop' 'rock' 'indie']
# ['pop' 'soul' 'contemporary']
# ['hip_hop' 'r&b' 'pop']
# ['hip_hop' 'rock' 'pop']
# ['pop' 'rock' 'punk']
# ['rock' 'pop' 'contemporary']
# ['rock' 'pop' 'contemporary']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'indie']
# ['trap' 'hip_hop' 'contemporary']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'rock' 'trap']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'house']
# ['rock' 'pop' 'screamo']
# ['rock' 'country' 'pop']
# ['hip_hop' 'pop' 'r&b']
# ['rock' 'pop' 'post-grunge']
# ['pop' 'contemporary' 'rock']
# ['rock' 'pop' 'soul']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'worship']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'screamo']
# ['stomp_and_holler' 'pop' 'rock']
# ['pop' 'contemporary' 'trap']
# ['hip_hop' 'trap' 'house']
# ['rock' 'pop' 'country']
# ['trap' 'hip_hop' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'stomp_and_holler' 'pop']
# ['pop' 'stomp_and_holler' 'rock']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'country' 'pop']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'rock' 'soul']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'indie']
# ['pop' 'house' 'hip_hop']
# ['rock' 'pop' 'hip_hop']
# ['hip_hop' 'contemporary' 'pop']
# ['trap' 'hip_hop' 'r&b']
# ['hip_hop' 'trap' 'contemporary']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'stomp_and_holler']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'trap' 'hip_hop']
# ['punk' 'rock' 'pop']
# ['pop' 'house' 'rock']
# ['pop' 'rock' 'country']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'hip_hop']
# ['indie' 'rock' 'stomp_and_holler']
# ['pop' 'rock' 'worship']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'soul' 'stomp_and_holler']
# ['rock' 'pop' 'singer-songwriter']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'pop' 'soul']
# ['pop' 'rock' 'stomp_and_holler']
# ['house' 'pop' 'rock']
# ['rock' 'pop' 'country']
# ['hip_hop' 'soul' 'pop']
# ['hip_hop' 'pop' 'contemporary']
# ['pop' 'rock' 'trap']
# ['rock' 'pop' 'punk']
# ['contemporary' 'pop' 'rock']
# ['pop' 'rock' 'stomp_and_holler']
# ['hip_hop' 'rock' 'trap']
# ['contemporary' 'pop' 'rock']
# ['hip_hop' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'soul' 'pop']
# ['hip_hop' 'contemporary' 'pop']
# ['contemporary' 'pop' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'stomp_and_holler']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'rock' 'contemporary']
# ['soul' 'rock' 'pop']
# ['pop' 'rock' 'house']
# ['pop' 'contemporary' 'rock']
# ['pop' 'rock' 'worship']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'jazz']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'worship']
# ['punk' 'rock' 'pop']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'soul']
# ['rock' 'singer-songwriter' 'pop']
# ['rock' 'country' 'pop']
# ['pop' 'rock' 'house']
# ['pop' 'contemporary' 'hip_hop']
# ['contemporary' 'hip_hop' 'trap']
# ['trap' 'hip_hop' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'country']
# ['pop' 'hip_hop' 'contemporary']
# ['rock' 'country' 'pop']
# ['singer-songwriter' 'rock' 'country']
# ['screamo' 'rock' 'pop']
# ['rock' 'pop' 'hip_hop']
# ['trap' 'hip_hop' 'contemporary']
# ['house' 'pop' 'rock']
# ['hip_hop' 'pop' 'reggae']
# ['rock' 'pop' 'country']
# ['reggae' 'trap' 'hip_hop']
# ['pop' 'trap' 'hip_hop']
# ['rock' 'stomp_and_holler' 'pop']
# ['pop' 'soul' 'indie']
# ['rock' 'pop' 'country']
# ['rock' 'indie' 'pop']
# ['pop' 'rock' 'contemporary']
# ['rock' 'stomp_and_holler' 'soul']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'rock' 'trap']
# ['rock' 'pop' 'post-grunge']
# ['country' 'rock' 'pop']
# ['pop' 'rock' 'house']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'contemporary']
# ['soul' 'rock' 'pop']
# ['rock' 'pop' 'punk']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'contemporary']
# ['trap' 'pop' 'house']
# ['pop' 'contemporary' 'rock']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'rock' 'contemporary']
# ['rock' 'worship' 'pop']
# ['pop' 'rock' 'house']
# ['pop' 'rock' 'contemporary']
# ['contemporary' 'hip_hop' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'contemporary' 'pop']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'trap' 'hip_hop']
# ['singer-songwriter' 'stomp_and_holler' 'rock']
# ['pop' 'contemporary' 'hip_hop']
# ['pop' 'stomp_and_holler' 'rock']
# ['pop' 'house' 'rock']
# ['rock' 'country' 'pop']
# ['pop' 'rock' 'contemporary']
# ['contemporary' 'rock' 'pop']
# ['pop' 'rock' 'house']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'stomp_and_holler' 'pop']
# ['hip_hop' 'trap' 'contemporary']
# ['rock' 'pop' 'indie']
# ['pop' 'rock' 'indie']
# ['pop' 'rock' 'contemporary']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'indie']
# ['house' 'pop' 'rock']
# ['trap' 'hip_hop' 'contemporary']
# ['trap' 'hip_hop' 'pop']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'pop' 'contemporary']
# ['rock' 'pop' 'screamo']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'pop' 'country']
# ['soul' 'pop' 'rock']
# ['rock' 'pop' 'house']
# ['soul' 'pop' 'rock']
# ['rock' 'pop' 'indie']
# ['pop' 'rock' 'house']
# ['pop' 'soul' 'hip_hop']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'pop' 'worship']
# ['rock' 'pop' 'contemporary']
# ['trap' 'pop' 'hip_hop']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'house']
# ['pop' 'stomp_and_holler' 'worship']
# ['rock' 'soul' 'pop']
# ['rock' 'pop' 'hip_hop']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'pop' 'hip_hop']
# ['pop' 'contemporary' 'trap']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'stomp_and_holler' 'indie']
# ['rock' 'pop' 'house']
# ['regional_mexican' 'rock' 'pop']
# ['pop' 'house' 'rock']
# ['country' 'rock' 'pop']
# ['rock' 'stomp_and_holler' 'jazz']
# ['pop' 'rock' 'indie']
# ['contemporary' 'pop' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'rock' 'indie']
# ['country' 'rock' 'pop']
# ['rock' 'pop' 'house']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'country']
# ['rock' 'indie' 'pop']
# ['pop' 'indie' 'rock']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'post-grunge']
# ['hip_hop' 'pop' 'house']
# ['pop' 'contemporary' 'hip_hop']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'country' 'soul']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'pop' 'house']
# ['stomp_and_holler' 'rock' 'punk']
# ['rock' 'pop' 'post-grunge']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'country' 'pop']
# ['rock' 'pop' 'contemporary']
# ['soul' 'rock' 'pop']
# ['rock' 'pop' 'contemporary']
# ['contemporary' 'pop' 'hip_hop']
# ['trap' 'pop' 'hip_hop']
# ['pop' 'rock' 'show_tunes']
# ['hip_hop' 'rock' 'contemporary']
# ['pop' 'rock' 'indie']
# ['pop' 'house' 'rock']
# ['hip_hop' 'trap' 'rock']
# ['pop' 'trap' 'hip_hop']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'country']
# ['pop' 'hip_hop' 'house']
# ['rock' 'indie' 'pop']
# ['pop' 'rock' 'country']
# ['pop' 'trap' 'hip_hop']
# ['rock' 'pop' 'country']
# ['pop' 'show_tunes' 'rock']
# ['pop' 'rock' 'worship']
# ['rock' 'pop' 'punk']
# ['house' 'pop' 'rock']
# ['rock' 'pop' 'hip_hop']
# ['pop' 'rock' 'country']
# ['pop' 'trap' 'house']
# ['rock' 'pop' 'reggae']
# ['trap' 'reggae' 'pop']
# ['show_tunes' 'hip_hop' 'pop']
# ['trap' 'pop' 'hip_hop']
# ['rock' 'soul' 'pop']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'punk' 'pop']
# ['punk' 'pop' 'rock']
# ['pop' 'indie' 'rock']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'contemporary']
# ['rock' 'pop' 'worship']
# ['trap' 'contemporary' 'pop']
# ['rock' 'pop' 'screamo']
# ['pop' 'hip_hop' 'rock']
# ['pop' 'rock' 'stomp_and_holler']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'trap' 'contemporary']
# ['house' 'pop' 'rock']
# ['pop' 'rock' 'hip_hop']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'indie' 'pop']
# ['pop' 'rock' 'trap']
# ['soul' 'rock' 'country']
# ['pop' 'house' 'trap']
# ['house' 'pop' 'hip_hop']
# ['pop' 'hip_hop' 'soul']
# ['country' 'rock' 'pop']
# ['rock' 'pop' 'post-grunge']
# ['contemporary' 'trap' 'hip_hop']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'hip_hop' 'trap']
# ['pop' 'rock' 'stomp_and_holler']
# ['pop' 'rock' 'country']
# ['contemporary' 'hip_hop' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'country']
# ['soul' 'hip_hop' 'pop']
# ['pop' 'rock' 'country']
# ['contemporary' 'pop' 'rock']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'house']
# ['regional_mexican' 'pop' 'rock']
# ['reggae' 'indie' 'rock']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'hip_hop']
# ['hip_hop' 'trap' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'country' 'pop']
# ['worship' 'pop' 'rock']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'country']
# ['show_tunes' 'pop' 'rock']
# ['rock' 'country' 'stomp_and_holler']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'house' 'rock']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'soul' 'contemporary']
# ['rock' 'show_tunes' 'pop']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'stomp_and_holler']
# ['hip_hop' 'trap' 'contemporary']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'hip_hop' 'pop']
# ['soul' 'rock' 'contemporary']
# ['pop' 'rock' 'country']
# ['stomp_and_holler' 'singer-songwriter' 'jazz']
# ['pop' 'indie' 'rock']
# ['rock' 'pop' 'house']
# ['screamo' 'rock' 'pop']
# ['hip_hop' 'pop' 'rock']
# ['pop' 'house' 'contemporary']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'country']
# ['country' 'rock' 'pop']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'worship']
# ['hip_hop' 'pop' 'contemporary']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'punk' 'pop']
# ['trap' 'pop' 'hip_hop']
# ['pop' 'rock' 'hip_hop']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'pop' 'indie']
# ['pop' 'rock' 'soul']
# ['rock' 'pop' 'hip_hop']
# ['trap' 'pop' 'hip_hop']
# ['rock' 'country' 'pop']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'country']
# ['pop' 'hip_hop' 'trap']
# ['rock' 'pop' 'country']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'worship']
# ['pop' 'rock' 'r&b']
# ['trap' 'hip_hop' 'pop']
# ['stomp_and_holler' 'rock' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'contemporary']
# ['pop' 'trap' 'hip_hop']
# ['pop' 'hip_hop' 'contemporary']
# ['rock' 'punk' 'pop']
# ['rock' 'pop' 'stomp_and_holler']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'house' 'trap']
# ['hip_hop' 'reggae' 'trap']
# ['rock' 'pop' 'contemporary']
# ['rock' 'soul' 'pop']
# ['pop' 'contemporary' 'regional_mexican']
# ['punk' 'rock' 'pop']
# ['rock' 'post-grunge' 'pop']
# ['rock' 'pop' 'indie']
# ['pop' 'hip_hop' 'trap']
# ['pop' 'rock' 'trap']
# ['hip_hop' 'trap' 'pop']
# ['house' 'rock' 'pop']
# ['pop' 'contemporary' 'show_tunes']
# ['rock' 'pop' 'soul']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'pop' 'post-grunge']
# ['hip_hop' 'pop' 'trap']
# ['post-grunge' 'rock' 'pop']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'contemporary' 'hip_hop']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'pop' 'house']
# ['rock' 'country' 'pop']
# ['house' 'rock' 'pop']
# ['rock' 'pop' 'worship']
# ['pop' 'rock' 'indie']
# ['pop' 'contemporary' 'hip_hop']
# ['pop' 'rock' 'singer-songwriter']
# ['pop' 'hip_hop' 'trap']
# ['jazz' 'hip_hop' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'country']
# ['house' 'pop' 'rock']
# ['rock' 'pop' 'house']
# ['jazz' 'stomp_and_holler' 'soul']
# ['pop' 'trap' 'hip_hop']
# ['rock' 'country' 'pop']
# ['country' 'rock' 'pop']
# ['hip_hop' 'trap' 'contemporary']
# ['rock' 'stomp_and_holler' 'pop']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'hip_hop']
# ['pop' 'indie' 'stomp_and_holler']
# ['pop' 'rock' 'worship']
# ['pop' 'rock' 'r&b']
# ['rock' 'pop' 'indie']
# ['hip_hop' 'pop' 'soul']
# ['country' 'rock' 'pop']
# ['pop' 'stomp_and_holler' 'rock']
# ['rock' 'pop' 'screamo']
# ['hip_hop' 'pop' 'trap']
# ['contemporary' 'hip_hop' 'pop']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'country']
# ['pop' 'hip_hop' 'house']
# ['punk' 'rock' 'pop']
# ['rock' 'pop' 'hip_hop']
# ['pop' 'hip_hop' 'trap']
# ['pop' 'hip_hop' 'rock']
# ['rock' 'country' 'pop']
# ['pop' 'hip_hop' 'trap']
# ['rock' 'country' 'singer-songwriter']
# ['trap' 'hip_hop' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'house']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'soul']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'reggae' 'rock']
# ['pop' 'hip_hop' 'trap']
# ['pop' 'rock' 'stomp_and_holler']
# ['worship' 'rock' 'pop']
# ['rock' 'stomp_and_holler' 'pop']
# ['pop' 'house' 'rock']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'stomp_and_holler' 'pop']
# ['rock' 'pop' 'country']
# ['trap' 'pop' 'hip_hop']
# ['house' 'hip_hop' 'trap']
# ['trap' 'hip_hop' 'pop']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'rock' 'worship']
# ['pop' 'soul' 'hip_hop']
# ['pop' 'rock' 'house']
# ['rock' 'pop' 'trap']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'rock' 'tropical']
# ['pop' 'hip_hop' 'contemporary']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'soul']
# ['stomp_and_holler' 'pop' 'rock']
# ['pop' 'contemporary' 'rock']
# ['hip_hop' 'trap' 'pop']
# ['hip_hop' 'trap' 'contemporary']
# ['pop' 'contemporary' 'rock']
# ['rock' 'pop' 'contemporary']
# ['rock' 'pop' 'country']
# ['punk' 'rock' 'screamo']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'trap' 'hip_hop']
# ['pop' 'stomp_and_holler' 'indie']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'hip_hop' 'trap']
# ['rock' 'pop' 'country']
# ['trap' 'hip_hop' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'stomp_and_holler']
# ['stomp_and_holler' 'pop' 'rock']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'post-grunge']
# ['pop' 'rock' 'hip_hop']
# ['stomp_and_holler' 'rock' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['trap' 'hip_hop' 'contemporary']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'punk']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'contemporary']
# ['show_tunes' 'worship' 'pop']
# ['pop' 'rock' 'hip_hop']
# ['indie' 'rock' 'pop']
# ['rock' 'pop' 'punk']
# ['post-grunge' 'rock' 'worship']
# ['rock' 'pop' 'post-grunge']
# ['rock' 'country' 'pop']
# ['pop' 'rock' 'contemporary']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'house']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'country']
# ['pop' 'hip_hop' 'contemporary']
# ['rock' 'pop' 'country']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'trap' 'rock']
# ['stomp_and_holler' 'pop' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'contemporary' 'hip_hop']
# ['pop' 'rock' 'trap']
# ['rock' 'pop' 'house']
# ['pop' 'rock' 'worship']
# ['trap' 'reggae' 'contemporary']
# ['rock' 'pop' 'stomp_and_holler']
# ['hip_hop' 'pop' 'rock']
# ['pop' 'hip_hop' 'trap']
# ['screamo' 'rock' 'pop']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'screamo']
# ['contemporary' 'pop' 'hip_hop']
# ['pop' 'rock' 'indie']
# ['rock' 'soul' 'stomp_and_holler']
# ['pop' 'hip_hop' 'rock']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'stomp_and_holler']
# ['pop' 'worship' 'rock']
# ['pop' 'contemporary' 'trap']
# ['stomp_and_holler' 'pop' 'rock']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'worship' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'country' 'pop']
# ['hip_hop' 'trap' 'contemporary']
# ['hip_hop' 'trap' 'pop']
# ['soul' 'pop' 'rock']
# ['rock' 'pop' 'indie']
# ['pop' 'rock' 'contemporary']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'country']
# ['rock' 'soul' 'pop']
# ['rock' 'hip_hop' 'pop']
# ['house' 'rock' 'pop']
# ['rock' 'pop' 'country']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'indie']
# ['hip_hop' 'trap' 'pop']
# ['stomp_and_holler' 'rock' 'jazz']
# ['pop' 'rock' 'r&b']
# ['rock' 'country' 'pop']
# ['hip_hop' 'trap' 'contemporary']
# ['pop' 'rock' 'soul']
# ['pop' 'rock' 'house']
# ['rock' 'stomp_and_holler' 'pop']
# ['pop' 'rock' 'contemporary']
# ['trap' 'pop' 'hip_hop']
# ['pop' 'rock' 'contemporary']
# ['pop' 'contemporary' 'trap']
# ['r&b' 'rock' 'pop']
# ['pop' 'house' 'soul']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'pop' 'country']
# ['contemporary' 'pop' 'rock']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'house']
# ['pop' 'contemporary' 'hip_hop']
# ['pop' 'hip_hop' 'trap']
# ['pop' 'contemporary' 'soul']
# ['hip_hop' 'trap' 'pop']
# ['hip_hop' 'trap' 'contemporary']
# ['rock' 'pop' 'indie']
# ['pop' 'hip_hop' 'trap']
# ['pop' 'rock' 'hip_hop']
# ['country' 'rock' 'pop']
# ['trap' 'contemporary' 'pop']
# ['rock' 'pop' 'contemporary']
# ['trap' 'hip_hop' 'pop']
# ['trap' 'pop' 'hip_hop']
# ['pop' 'stomp_and_holler' 'indie']
# ['rock' 'pop' 'hip_hop']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'house']
# ['pop' 'contemporary' 'rock']
# ['indie' 'rock' 'pop']
# ['soul' 'rock' 'pop']
# ['pop' 'hip_hop' 'contemporary']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'country']
# ['pop' 'indie' 'stomp_and_holler']
# ['rock' 'country' 'pop']
# ['rock' 'pop' 'indie']
# ['pop' 'rock' 'show_tunes']
# ['pop' 'hip_hop' 'trap']
# ['screamo' 'pop' 'rock']
# ['hip_hop' 'trap' 'contemporary']
# ['contemporary' 'pop' 'rock']
# ['rock' 'pop' 'soul']
# ['pop' 'rock' 'country']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'contemporary']
# ['punk' 'rock' 'pop']
# ['rock' 'pop' 'worship']
# ['pop' 'trap' 'hip_hop']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'trap' 'hip_hop']
# ['pop' 'rock' 'hip_hop']
# ['pop' 'rock' 'trap']
# ['punk' 'rock' 'worship']
# ['pop' 'rock' 'house']
# ['rock' 'pop' 'contemporary']
# ['pop' 'rock' 'soul']
# ['rock' 'pop' 'house']
# ['hip_hop' 'trap' 'pop']
# ['worship' 'pop' 'rock']
# ['rock' 'pop' 'punk']
# ['rock' 'stomp_and_holler' 'pop']
# ['hip_hop' 'trap' 'contemporary']
# ['worship' 'rock' 'pop']
# ['hip_hop' 'contemporary' 'trap']
# ['rock' 'pop' 'indie']
# ['pop' 'rock' 'country']
# ['r&b' 'contemporary' 'pop']
# ['pop' 'contemporary' 'rock']
# ['rock' 'stomp_and_holler' 'pop']
# ['pop' 'rock' 'contemporary']
# ['rock' 'punk' 'pop']
# ['pop' 'hip_hop' 'trap']
# ['pop' 'rock' 'indie']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'contemporary']
# ['stomp_and_holler' 'pop' 'soul']
# ['pop' 'rock' 'house']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'worship']
# ['pop' 'rock' 'house']
# ['trap' 'hip_hop' 'contemporary']
# ['hip_hop' 'trap' 'pop']
# ['contemporary' 'trap' 'hip_hop']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'indie']
# ['trap' 'hip_hop' 'pop']
# ['screamo' 'pop' 'rock']
# ['house' 'pop' 'rock']
# ['hip_hop' 'trap' 'pop']
# ['hip_hop' 'trap' 'contemporary']
# ['indie' 'pop' 'singer-songwriter']
# ['pop' 'rock' 'stomp_and_holler']
# ['hip_hop' 'rock' 'contemporary']
# ['rock' 'pop' 'worship']
# ...
# ['trap' 'hip_hop' 'pop']
# ['pop' 'hip_hop' 'house']
# ['rock' 'country' 'soul']
# ['worship' 'pop' 'rock']
# ['reggae' 'hip_hop' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'house']
# ['pop' 'hip_hop' 'trap']
# ['hip_hop' 'trap' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'trap']
# ['rock' 'pop' 'house']
# ['rock' 'pop' 'indie']
# ['pop' 'rock' 'trap']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'country']
# ['reggae' 'pop' 'rock']
# ['pop' 'rock' 'contemporary']
# ['rock' 'r&b' 'pop']
# ['pop' 'rock' 'country']
# ['rock' 'country' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['trap' 'pop' 'r&b']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'contemporary']
# ['pop' 'trap' 'rock']
# ['rock' 'pop' 'contemporary']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'contemporary']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'house']
# ['pop' 'rock' 'stomp_and_holler']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'house']
# ['regional_mexican' 'rock' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'house']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'trap' 'rock']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'house']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'contemporary']
# ['rock' 'pop' 'indie']
# ['trap' 'pop' 'hip_hop']
# ['hip_hop' 'trap' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'hip_hop']
# ['pop' 'hip_hop' 'rock']
# ['pop' 'trap' 'contemporary']
# ['rock' 'stomp_and_holler' 'singer-songwriter']
# ['rock' 'soul' 'tropical']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'pop' 'country']
# ['rock' 'country' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['hip_hop' 'contemporary' 'pop']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'pop' 'punk']
# ['hip_hop' 'trap' 'pop']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'indie' 'stomp_and_holler']
# ['jazz' 'stomp_and_holler' 'rock']
# ['pop' 'indie' 'show_tunes']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'hip_hop' 'punk']
# ['rock' 'stomp_and_holler' 'pop']
# ['pop' 'indie' 'rock']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'country']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'country']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'stomp_and_holler']
# ['trap' 'pop' 'reggae']
# ['stomp_and_holler' 'rock' 'pop']
# ['pop' 'indie' 'stomp_and_holler']
# ['rock' 'pop' 'punk']
# ['house' 'pop' 'rock']
# ['pop' 'soul' 'hip_hop']
# ['pop' 'rock' 'stomp_and_holler']
# ['pop' 'rock' 'contemporary']
# ['post-grunge' 'rock' 'pop']
# ['pop' 'house' 'rock']
# ['trap' 'contemporary' 'soul']
# ['pop' 'stomp_and_holler' 'rock']
# ['rock' 'pop' 'country']
# ['pop' 'trap' 'house']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'stomp_and_holler']
# ['pop' 'rock' 'house']
# ['contemporary' 'pop' 'rock']
# ['pop' 'reggae' 'rock']
# ['pop' 'rock' 'house']
# ['rock' 'pop' 'country']
# ['trap' 'pop' 'hip_hop']
# ['rock' 'pop' 'punk']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'worship']
# ['trap' 'pop' 'hip_hop']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'contemporary' 'hip_hop']
# ['trap' 'pop' 'rock']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'pop' 'country']
# ['hip_hop' 'trap' 'pop']
# ['trap' 'pop' 'contemporary']
# ['pop' 'hip_hop' 'house']
# ['rock' 'tropical' 'pop']
# ['pop' 'hip_hop' 'trap']
# ['rock' 'pop' 'hip_hop']
# ['pop' 'rock' 'country']
# ['pop' 'rock' 'stomp_and_holler']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'trap' 'reggae']
# ['rock' 'pop' 'soul']
# ['pop' 'contemporary' 'rock']
# ['rock' 'country' 'pop']
# ['rock' 'soul' 'pop']
# ['pop' 'house' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'contemporary']
# ['soul' 'pop' 'rock']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'worship']
# ['pop' 'rock' 'contemporary']
# ['screamo' 'indie' 'rock']
# ['rock' 'pop' 'worship']
# ['worship' 'rock' 'pop']
# ['pop' 'rock' 'screamo']
# ['rock' 'indie' 'pop']
# ['pop' 'contemporary' 'rock']
# ['rock' 'pop' 'worship']
# ['pop' 'house' 'hip_hop']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'singer-songwriter']
# ['rock' 'country' 'pop']
# ['pop' 'rock' 'house']
# ['rock' 'country' 'pop']
# ['pop' 'stomp_and_holler' 'rock']
# ['pop' 'hip_hop' 'trap']
# ['contemporary' 'pop' 'rock']
# ['pop' 'house' 'rock']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'pop' 'house']
# ['rock' 'hip_hop' 'pop']
# ['rock' 'pop' 'stomp_and_holler']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'house' 'rock']
# ['rock' 'pop' 'reggae']
# ['rock' 'punk' 'pop']
# ['pop' 'hip_hop' 'trap']
# ['rock' 'stomp_and_holler' 'singer-songwriter']
# ['rock' 'indie' 'pop']
# ['contemporary' 'rock' 'pop']
# ['rock' 'pop' 'worship']
# ['hip_hop' 'pop' 'rock']
# ['pop' 'rock' 'country']
# ['pop' 'rock' 'worship']
# ['pop' 'rock' 'contemporary']
# ['pop' 'trap' 'rock']
# ['pop' 'rock' 'show_tunes']
# ['rock' 'pop' 'indie']
# ['pop' 'contemporary' 'hip_hop']
# ['rock' 'pop' 'post-grunge']
# ['pop' 'contemporary' 'trap']
# ['pop' 'hip_hop' 'trap']
# ['pop' 'rock' 'house']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'contemporary' 'rock']
# ['pop' 'house' 'trap']
# ['pop' 'hip_hop' 'rock']
# ['rock' 'pop' 'house']
# ['pop' 'rock' 'worship']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'country']
# ['house' 'rock' 'pop']
# ['contemporary' 'pop' 'hip_hop']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'indie']
# ['pop' 'hip_hop' 'trap']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'punk']
# ['rock' 'pop' 'house']
# ['rock' 'pop' 'post-grunge']
# ['rock' 'pop' 'country']
# ['trap' 'contemporary' 'pop']
# ['pop' 'rock' 'trap']
# ['pop' 'contemporary' 'hip_hop']
# ['pop' 'rock' 'worship']
# ['rock' 'pop' 'house']
# ['hip_hop' 'pop' 'rock']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'pop' 'soul']
# ['hip_hop' 'pop' 'trap']
# ['trap' 'hip_hop' 'pop']
# ['hip_hop' 'trap' 'contemporary']
# ['hip_hop' 'trap' 'contemporary']
# ['trap' 'hip_hop' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['contemporary' 'pop' 'hip_hop']
# ['rock' 'pop' 'stomp_and_holler']
# ['stomp_and_holler' 'pop' 'rock']
# ['pop' 'rock' 'country']
# ['rock' 'country' 'pop']
# ['singer-songwriter' 'jazz' 'stomp_and_holler']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'house']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'soul' 'pop']
# ['house' 'pop' 'rock']
# ['pop' 'hip_hop' 'trap']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'contemporary']
# ['trap' 'house' 'pop']
# ['rock' 'pop' 'soul']
# ['pop' 'hip_hop' 'rock']
# ['rock' 'stomp_and_holler' 'pop']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'worship']
# ['country' 'rock' 'pop']
# ['contemporary' 'pop' 'reggae']
# ['hip_hop' 'trap' 'contemporary']
# ['screamo' 'rock' 'pop']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'house']
# ['pop' 'rock' 'hip_hop']
# ['contemporary' 'pop' 'rock']
# ['rock' 'pop' 'punk']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'soul']
# ['house' 'pop' 'contemporary']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'worship' 'pop']
# ['pop' 'trap' 'house']
# ['hip_hop' 'trap' 'contemporary']
# ['pop' 'trap' 'hip_hop']
# ['country' 'rock' 'trap']
# ['rock' 'pop' 'soul']
# ['rock' 'pop' 'country']
# ['hip_hop' 'pop' 'rock']
# ['pop' 'hip_hop' 'trap']
# ['pop' 'contemporary' 'rock']
# ['pop' 'screamo' 'rock']
# ['contemporary' 'pop' 'hip_hop']
# ['rock' 'pop' 'punk']
# ['pop' 'rock' 'house']
# ['rock' 'pop' 'country']
# ['trap' 'hip_hop' 'pop']
# ['indie' 'screamo' 'pop']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'pop' 'country']
# ['trap' 'hip_hop' 'rock']
# ['pop' 'rock' 'r&b']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'trap' 'rock']
# ['hip_hop' 'trap' 'contemporary']
# ['trap' 'hip_hop' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'worship']
# ['rock' 'pop' 'contemporary']
# ['pop' 'worship' 'contemporary']
# ['hip_hop' 'pop' 'trap']
# ['country' 'rock' 'pop']
# ['trap' 'pop' 'contemporary']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'rock' 'contemporary']
# ['trap' 'pop' 'hip_hop']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'stomp_and_holler']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'hip_hop' 'show_tunes']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'indie']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'rock' 'country']
# ['pop' 'rock' 'country']
# ['pop' 'rock' 'trap']
# ['hip_hop' 'trap' 'reggae']
# ['rock' 'house' 'pop']
# ['house' 'pop' 'hip_hop']
# ['contemporary' 'pop' 'stomp_and_holler']
# ['trap' 'hip_hop' 'house']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'worship']
# ['rock' 'pop' 'country']
# ['worship' 'pop' 'rock']
# ['rock' 'stomp_and_holler' 'pop']
# ['contemporary' 'pop' 'worship']
# ['rock' 'pop' 'indie']
# ['pop' 'rock' 'country']
# ['rock' 'soul' 'pop']
# ['rock' 'pop' 'indie']
# ['house' 'pop' 'rock']
# ['rock' 'pop' 'soul']
# ['pop' 'trap' 'rock']
# ['pop' 'rock' 'indie']
# ['pop' 'rock' 'contemporary']
# ['country' 'rock' 'pop']
# ['rock' 'pop' 'screamo']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'house']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'hip_hop']
# ['pop' 'trap' 'contemporary']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'country']
# ['pop' 'rock' 'stomp_and_holler']
# ['pop' 'rock' 'contemporary']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'tropical' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'country']
# ['stomp_and_holler' 'rock' 'pop']
# ['trap' 'hip_hop' 'contemporary']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'country']
# ['rock' 'stomp_and_holler' 'pop']
# ['trap' 'pop' 'contemporary']
# ['rock' 'pop' 'contemporary']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'singer-songwriter']
# ['rock' 'pop' 'screamo']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'rock' 'house']
# ['pop' 'stomp_and_holler' 'soul']
# ['pop' 'rock' 'soul']
# ['rock' 'pop' 'country']
# ['contemporary' 'hip_hop' 'trap']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'contemporary' 'rock']
# ['hip_hop' 'trap' 'pop']
# ['contemporary' 'pop' 'trap']
# ['hip_hop' 'pop' 'contemporary']
# ['pop' 'rock' 'contemporary']
# ['hip_hop' 'trap' 'contemporary']
# ['rock' 'pop' 'punk']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'worship']
# ['trap' 'pop' 'hip_hop']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'soul']
# ['rock' 'pop' 'country']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'punk']
# ['hip_hop' 'trap' 'pop']
# ['contemporary' 'pop' 'rock']
# ['singer-songwriter' 'rock' 'pop']
# ['pop' 'rock' 'hip_hop']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'worship']
# ['rock' 'stomp_and_holler' 'pop']
# ['house' 'trap' 'pop']
# ['rock' 'indie' 'pop']
# ['pop' 'trap' 'hip_hop']
# ['rock' 'pop' 'stomp_and_holler']
# ['worship' 'pop' 'rock']
# ['pop' 'hip_hop' 'trap']
# ['rock' 'pop' 'contemporary']
# ['trap' 'pop' 'hip_hop']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'contemporary']
# ['pop' 'rock' 'show_tunes']
# ['trap' 'pop' 'contemporary']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'house']
# ['pop' 'rock' 'worship']
# ['contemporary' 'pop' 'hip_hop']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'indie']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'pop' 'country']
# ['contemporary' 'pop' 'rock']
# ['pop' 'trap' 'hip_hop']
# ['pop' 'rock' 'hip_hop']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'stomp_and_holler' 'rock']
# ['trap' 'hip_hop' 'pop']
# ['hip_hop' 'trap' 'contemporary']
# ['house' 'pop' 'rock']
# ['rock' 'pop' 'hip_hop']
# ['rock' 'soul' 'pop']
# ['trap' 'hip_hop' 'contemporary']
# ['hip_hop' 'trap' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['house' 'rock' 'pop']
# ['pop' 'house' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'soul' 'stomp_and_holler']
# ['pop' 'r&b' 'contemporary']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'contemporary']
# ['stomp_and_holler' 'rock' 'pop']
# ['pop' 'rock' 'stomp_and_holler']
# ['pop' 'house' 'trap']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'punk']
# ['soul' 'rock' 'pop']
# ['rock' 'post-grunge' 'pop']
# ['pop' 'rock' 'contemporary']
# ['hip_hop' 'trap' 'pop']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'indie' 'pop']
# ['rock' 'pop' 'contemporary']
# ['rock' 'pop' 'contemporary']
# ['hip_hop' 'contemporary' 'trap']
# ['rock' 'worship' 'pop']
# ['pop' 'contemporary' 'hip_hop']
# ['jazz' 'rock' 'show_tunes']
# ['stomp_and_holler' 'pop' 'rock']
# ['hip_hop' 'pop' 'trap']
# ['rock' 'pop' 'punk']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'rock' 'stomp_and_holler']
# ['trap' 'pop' 'hip_hop']
# ['stomp_and_holler' 'rock' 'pop']
# ['pop' 'indie' 'rock']
# ['pop' 'hip_hop' 'trap']
# ['hip_hop' 'pop' 'trap']
# ['country' 'rock' 'pop']
# ['trap' 'pop' 'hip_hop']
# ['pop' 'rock' 'house']
# ['rock' 'country' 'soul']
# ['regional_mexican' 'pop' 'hip_hop']
# ['rock' 'pop' 'contemporary']
# ['trap' 'pop' 'hip_hop']
# ['contemporary' 'trap' 'hip_hop']
# ['pop' 'contemporary' 'rock']
# ['rock' 'stomp_and_holler' 'pop']
# ['pop' 'rock' 'hip_hop']
# ['pop' 'rock' 'hip_hop']
# ['rock' 'pop' 'house']
# ['rock' 'pop' 'screamo']
# ['rock' 'stomp_and_holler' 'pop']
# ['hip_hop' 'trap' 'contemporary']
# ['pop' 'rock' 'house']
# ['rock' 'pop' 'country']
# ['pop' 'contemporary' 'trap']
# ['rock' 'stomp_and_holler' 'soul']
# ['hip_hop' 'trap' 'pop']
# ['pop' 'trap' 'rock']
# ['rock' 'pop' 'house']
# ['regional_mexican' 'rock' 'pop']
# ['rock' 'country' 'pop']
# ['pop' 'trap' 'hip_hop']
# ['pop' 'rock' 'worship']
# ['pop' 'rock' 'country']
# ['trap' 'pop' 'hip_hop']
# ['show_tunes' 'hip_hop' 'pop']
# ['rock' 'pop' 'country']
# ['pop' 'rock' 'worship']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'country']
# ['indie' 'pop' 'rock']
# ['trap' 'hip_hop' 'contemporary']
# ['pop' 'stomp_and_holler' 'rock']
# ['rock' 'pop' 'country']
# ['trap' 'contemporary' 'pop']
# ['jazz' 'rock' 'pop']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'country']
# ['trap' 'rock' 'pop']
# ['pop' 'trap' 'contemporary']
# ['pop' 'rock' 'hip_hop']
# ['hip_hop' 'trap' 'pop']
# ['contemporary' 'hip_hop' 'pop']
# ['pop' 'hip_hop' 'contemporary']
# ['pop' 'contemporary' 'trap']
# ['trap' 'contemporary' 'hip_hop']
# ['rock' 'pop' 'house']
# ['pop' 'contemporary' 'r&b']
# ['rock' 'worship' 'pop']
# ['hip_hop' 'contemporary' 'pop']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'country']
# ['pop' 'hip_hop' 'rock']
# ['rock' 'country' 'pop']
# ['rock' 'stomp_and_holler' 'pop']
# ['pop' 'country' 'rock']
# ['hip_hop' 'trap' 'pop']
# ['hip_hop' 'rock' 'pop']
# ['stomp_and_holler' 'pop' 'jazz']
# ['house' 'pop' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['rock' 'pop' 'house']
# ['pop' 'rock' 'hip_hop']
# ['pop' 'rock' 'singer-songwriter']
# ['country' 'pop' 'rock']
# ['hip_hop' 'pop' 'contemporary']
# ['rock' 'pop' 'stomp_and_holler']
# ['hip_hop' 'contemporary' 'trap']
# ['rock' 'pop' 'indie']
# ['hip_hop' 'pop' 'trap']
# ['pop' 'rock' 'hip_hop']
# ['pop' 'country' 'rock']
# ['pop' 'rock' 'indie']
# ['pop' 'rock' 'contemporary']
# ['rock' 'pop' 'country']
# ['stomp_and_holler' 'rock' 'singer-songwriter']
# ['pop' 'stomp_and_holler' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'hip_hop' 'trap']
# ['jazz' 'pop' 'rock']
# ['rock' 'pop' 'screamo']
# ['pop' 'rock' 'contemporary']
# ['hip_hop' 'trap' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['rock' 'pop' 'indie']
# ['pop' 'stomp_and_holler' 'rock']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'country']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'stomp_and_holler']
# ['rock' 'pop' 'stomp_and_holler']
# ['pop' 'indie' 'rock']
# ['pop' 'hip_hop' 'rock']
# ['rock' 'pop' 'stomp_and_holler']
# ['trap' 'hip_hop' 'contemporary']
# ['hip_hop' 'trap' 'pop']
# ['trap' 'pop' 'rock']
# ['hip_hop' 'pop' 'contemporary']
# ['tropical' 'regional_mexican' 'pop']
# ['trap' 'pop' 'hip_hop']
# ['pop' 'trap' 'rock']
# ['rock' 'pop' 'house']
# ['rock' 'pop' 'country']
# ['trap' 'hip_hop' 'contemporary']
# ['trap' 'hip_hop' 'pop']
# ['rock' 'pop' 'trap']
# ['rock' 'pop' 'hip_hop']
# ['singer-songwriter' 'rock' 'pop']
# ['rock' 'pop' 'country']
# ['pop' 'hip_hop' 'trap']
# ['pop' 'rock' 'hip_hop']
# ['pop' 'rock' 'hip_hop']
# ['trap' 'pop' 'hip_hop']
# ['pop' 'rock' 'country']
# ['pop' 'rock' 'trap']
# ['pop' 'rock' 'soul']
# ['pop' 'trap' 'hip_hop']
# ['contemporary' 'pop' 'hip_hop']
# ['rock' 'soul' 'country']
# ['rock' 'pop' 'indie']
# ['show_tunes' 'pop' 'r&b']
# ['rock' 'pop' 'indie']
# ['house' 'pop' 'rock']
# ['rock' 'pop' 'country']
# ['rock' 'pop' 'singer-songwriter']
# ['pop' 'contemporary' 'rock']
# ['pop' 'house' 'rock']
# ['hip_hop' 'show_tunes' 'contemporary']
# ['pop' 'contemporary' 'rock']
# ['rock' 'hip_hop' 'pop']
# ['rock' 'pop' 'indie']
# ['pop' 'contemporary' 'soul']
# ['pop' 'rock' 'contemporary']
# ['country' 'rock' 'pop']
# ['hip_hop' 'trap' 'pop']
# ['trap' 'hip_hop' 'pop']
# ['pop' 'rock' 'worship']
# ['regional_mexican' 'rock' 'country']
# ['pop' 'rock' 'house']
# ['pop' 'rock' 'indie']
# ['worship' 'pop' 'rock']
# ['pop' 'rock' 'country']
# ['rock' 'pop' 'hip_hop']
# ['pop' 'contemporary' 'hip_hop']
# ['rock' 'country' 'pop']

# %%
print(classification_report(y_test,mdfd_pred ))
# Out:
#                    precision    recall  f1-score   support
#
#      contemporary       0.75      0.53      0.62       216
#           country       0.89      0.61      0.72       147
#           hip_hop       0.74      0.80      0.77       414
#             house       0.87      0.56      0.68       140
#             indie       0.77      0.23      0.36       115
#              jazz       0.63      0.27      0.38        63
#               pop       0.71      0.97      0.82       945
#       post-grunge       0.20      0.05      0.08        20
#              punk       0.74      0.37      0.49        46
#               r&b       0.33      0.04      0.07        53
#            reggae       0.33      0.12      0.18        42
#  regional_mexican       0.79      0.56      0.65        27
#              rock       0.69      0.94      0.80       817
#           screamo       0.86      0.23      0.36        52
#        show_tunes       0.62      0.24      0.34        42
# singer-songwriter       0.67      0.10      0.17        41
#              soul       0.71      0.27      0.39       125
#  stomp_and_holler       0.73      0.45      0.56       140
#              trap       0.85      0.82      0.83       368
#          tropical       0.50      0.20      0.29        20
#           worship       0.72      0.48      0.58        79
#
#          accuracy                           0.73      3912
#         macro avg       0.67      0.42      0.48      3912
#      weighted avg       0.73      0.73      0.70      3912
